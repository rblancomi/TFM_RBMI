# %% [markdown]
# # Pool discovered degrons that overlap

# %% [markdown]
# This notebook contains the code to merge the overlapping degrons discovered for downstream functional validation.

# %% [markdown]
# Some degrons motifs are very degenerated and, thus, degron boundaries can be difficult to define. Steps:
# 1. Study the amount of degrons having this condition.
# 2. Pool degrons that overlap (even in a single position).

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import os
import sys

## my modules ##
sys.path.append("../scripts/Utils/")    # modules folder
from fasta_utils import readFasta_gzip

# %% [markdown]
# ## Define variables and paths

# %%
base = "../"

results = "results/"

all_discov_degrons_path = os.path.join(base, results, "discovered_degrons/proteome_20k/")
all_discov_degrons_overlapool_path = os.path.join(base, results, "discovered_degrons/proteome_20k_overlapping_pooled/")

proteome_path = os.path.join(base, data, "external/biomart/biomart92_proteome_cantranscripts_uniq_prepro.fasta.gz")

# %%
# Load proteome 

proteome = readFasta_gzip(proteome_path)
# Out:
# Number of retrieved sequences: 19302

# %% [markdown]
# ## 1. Find overlapping degrons in the raw tables of discovered degrons per motif

# %% [markdown]
# These are the tables directly generated from the scan files.

# %%
motifs = os.listdir(all_discov_degrons_path)

lengths = []  # to monitor max degron length obtain after pooling

# One by one motif analysis
for motif in motifs:
    
    print()
    print(f'Motif: {motif}')
    print()
    
    discov_degrons = pd.read_csv(all_discov_degrons_path+motif, sep = "\t", compression = "gzip")
    
    # Obtain proteins having the same degron discovered more than once
    discov_degrons_c = discov_degrons.groupby(["protein_id"]).size(
    ).reset_index().rename(columns = {0:'count'})
    discov_degrons_c_more1_id = discov_degrons_c.loc[discov_degrons_c["count"] > 1, "protein_id"].values
    
    # For each protein, obtain all the coordinates of the found degrons
    for id in discov_degrons_c_more1_id:
        
        degron_starts = discov_degrons.loc[discov_degrons.protein_id == id, "start"].values
        degron_ends = discov_degrons.loc[discov_degrons.protein_id == id, "end"].values
            
        first = True   # flag variable
        
        # List for new pooled intervals
        degrons_pooled_intervals = []
        
        for ds, de in zip(degron_starts, degron_ends):  # can be done this way because degrons are linearly ordered
                                                        # upon discovery
            # First degron interval in the protein
            if first:
                first = False
                degron_interval = (ds, de)
            
            # Pool degrons: overlap
            elif (degron_interval[0] < ds and degron_interval[1] > ds) or \
                (degron_interval[0] < de and degron_interval[1] > de):
                    degron_interval = (min([degron_interval[0], ds]), 
                                       max([degron_interval[1], de]))
            
            # New interval starting            
            else:
                degrons_pooled_intervals.append(degron_interval)
                degron_interval = (ds, de)
        
        # Final list of degron intervals for the specific protein
        degrons_pooled_intervals.append(degron_interval)
        
        # Per motif: print those proteins for which we have pooled overlapping degrons
        if len(degron_starts) > len(degrons_pooled_intervals):
            print(f'\tDegron discovered in protein {id}')
            print(f'\tInitial number of discovered degrons: {len(degron_starts)}')
            for ds, de in zip(degron_starts, degron_ends):
                print(f'\t\tLength of{ds, de}: {de-ds}')
            print(f'\tFinal number of discovered degrons: {len(degrons_pooled_intervals)}')
            print(f'\t\t{degrons_pooled_intervals}')
            for inter in degrons_pooled_intervals:
                print(f'\t\tLength of {inter}: {inter[1]-inter[0]}')
                lengths.append(inter[1]-inter[0])
            print()

# Print the maximum degron length we obtain after overlapping
print(f'Maximum degron length obtained after pooling all overlapping degrons: {max(lengths)}')
# Out:
# Motif: APC_ABBA.tsv.gz
#
#
# Motif: APC_KENBOX.tsv.gz
#
# 	Degron discovered in protein ENST00000319653
# 	Initial number of discovered degrons: 2
# 		Length of(1602, 1611): 9
# 		Length of(1609, 1618): 9
# 	Final number of discovered degrons: 1
# 		[(1602, 1618)]
# 		Length of (1602, 1618): 16
#
# 	Degron discovered in protein ENST00000320005
# 	Initial number of discovered degrons: 2
# 		Length of(720, 729): 9
# 		Length of(727, 736): 9
# 	Final number of discovered degrons: 1
# 		[(720, 736)]
# 		Length of (720, 736): 16
#
# 	Degron discovered in protein ENST00000334352
# 	Initial number of discovered degrons: 2
# 		Length of(176, 185): 9
# 		Length of(181, 190): 9
# 	Final number of discovered degrons: 1
# 		[(176, 190)]
# 		Length of (176, 190): 14
#
#
# Motif: BTRC.tsv.gz
#
#
# Motif: CBLL1.tsv.gz
#
#
# Motif: CBL_MET.tsv.gz
#
# 	Degron discovered in protein ENST00000260988
# 	Initial number of discovered degrons: 2
# 		Length of(133, 148): 15
# 		Length of(135, 150): 15
# 	Final number of discovered degrons: 1
# 		[(133, 150)]
# 		Length of (133, 150): 17
#
# 	Degron discovered in protein ENST00000284110
# 	Initial number of discovered degrons: 2
# 		Length of(81, 96): 15
# 		Length of(92, 107): 15
# 	Final number of discovered degrons: 1
# 		[(81, 107)]
# 		Length of (81, 107): 26
#
# 	Degron discovered in protein ENST00000352681
# 	Initial number of discovered degrons: 2
# 		Length of(112, 127): 15
# 		Length of(117, 132): 15
# 	Final number of discovered degrons: 1
# 		[(112, 132)]
# 		Length of (112, 132): 20
#
# 	Degron discovered in protein ENST00000354212
# 	Initial number of discovered degrons: 5
# 		Length of(1084, 1099): 15
# 		Length of(1099, 1114): 15
# 		Length of(1107, 1122): 15
# 		Length of(1115, 1130): 15
# 		Length of(1130, 1145): 15
# 	Final number of discovered degrons: 3
# 		[(1084, 1099), (1099, 1130), (1130, 1145)]
# 		Length of (1084, 1099): 15
# 		Length of (1099, 1130): 31
# 		Length of (1130, 1145): 15
#
# 	Degron discovered in protein ENST00000354777
# 	Initial number of discovered degrons: 2
# 		Length of(243, 258): 15
# 		Length of(245, 260): 15
# 	Final number of discovered degrons: 1
# 		[(243, 260)]
# 		Length of (243, 260): 17
#
# 	Degron discovered in protein ENST00000361170
# 	Initial number of discovered degrons: 2
# 		Length of(800, 815): 15
# 		Length of(804, 819): 15
# 	Final number of discovered degrons: 1
# 		[(800, 819)]
# 		Length of (800, 819): 19
#
# 	Degron discovered in protein ENST00000367714
# 	Initial number of discovered degrons: 2
# 		Length of(613, 628): 15
# 		Length of(615, 630): 15
# 	Final number of discovered degrons: 1
# 		[(613, 630)]
# 		Length of (613, 630): 17
#
# 	Degron discovered in protein ENST00000368642
# 	Initial number of discovered degrons: 2
# 		Length of(3, 18): 15
# 		Length of(13, 28): 15
# 	Final number of discovered degrons: 1
# 		[(3, 28)]
# 		Length of (3, 28): 25
#
# 	Degron discovered in protein ENST00000373069
# 	Initial number of discovered degrons: 2
# 		Length of(178, 193): 15
# 		Length of(181, 196): 15
# 	Final number of discovered degrons: 1
# 		[(178, 196)]
# 		Length of (178, 196): 18
#
# 	Degron discovered in protein ENST00000374080
# 	Initial number of discovered degrons: 4
# 		Length of(228, 243): 15
# 		Length of(2067, 2082): 15
# 		Length of(2070, 2085): 15
# 		Length of(2081, 2096): 15
# 	Final number of discovered degrons: 2
# 		[(228, 243), (2067, 2096)]
# 		Length of (228, 243): 15
# 		Length of (2067, 2096): 29
#
# 	Degron discovered in protein ENST00000374796
# 	Initial number of discovered degrons: 3
# 		Length of(1025, 1040): 15
# 		Length of(1026, 1041): 15
# 		Length of(1028, 1043): 15
# 	Final number of discovered degrons: 1
# 		[(1025, 1043)]
# 		Length of (1025, 1043): 18
#
# 	Degron discovered in protein ENST00000375915
# 	Initial number of discovered degrons: 2
# 		Length of(79, 94): 15
# 		Length of(81, 96): 15
# 	Final number of discovered degrons: 1
# 		[(79, 96)]
# 		Length of (79, 96): 17
#
# 	Degron discovered in protein ENST00000389494
# 	Initial number of discovered degrons: 2
# 		Length of(76, 91): 15
# 		Length of(78, 93): 15
# 	Final number of discovered degrons: 1
# 		[(76, 93)]
# 		Length of (76, 93): 17
#
# 	Degron discovered in protein ENST00000394196
# 	Initial number of discovered degrons: 2
# 		Length of(1653, 1668): 15
# 		Length of(1663, 1678): 15
# 	Final number of discovered degrons: 1
# 		[(1653, 1678)]
# 		Length of (1653, 1678): 25
#
# 	Degron discovered in protein ENST00000421745
# 	Initial number of discovered degrons: 3
# 		Length of(294, 309): 15
# 		Length of(1049, 1064): 15
# 		Length of(1050, 1065): 15
# 	Final number of discovered degrons: 2
# 		[(294, 309), (1049, 1065)]
# 		Length of (294, 309): 15
# 		Length of (1049, 1065): 16
#
# 	Degron discovered in protein ENST00000456080
# 	Initial number of discovered degrons: 4
# 		Length of(60, 75): 15
# 		Length of(61, 76): 15
# 		Length of(66, 81): 15
# 		Length of(103, 118): 15
# 	Final number of discovered degrons: 2
# 		[(60, 81), (103, 118)]
# 		Length of (60, 81): 21
# 		Length of (103, 118): 15
#
# 	Degron discovered in protein ENST00000517956
# 	Initial number of discovered degrons: 2
# 		Length of(191, 206): 15
# 		Length of(192, 207): 15
# 	Final number of discovered degrons: 1
# 		[(191, 207)]
# 		Length of (191, 207): 16
#
# 	Degron discovered in protein ENST00000536005
# 	Initial number of discovered degrons: 2
# 		Length of(53, 68): 15
# 		Length of(63, 78): 15
# 	Final number of discovered degrons: 1
# 		[(53, 78)]
# 		Length of (53, 78): 25
#
#
# Motif: CBL_PTK.tsv.gz
#
# 	Degron discovered in protein ENST00000392379
# 	Initial number of discovered degrons: 2
# 		Length of(314, 326): 12
# 		Length of(322, 334): 12
# 	Final number of discovered degrons: 1
# 		[(314, 334)]
# 		Length of (314, 334): 20
#
# 	Degron discovered in protein ENST00000452236
# 	Initial number of discovered degrons: 2
# 		Length of(477, 489): 12
# 		Length of(481, 493): 12
# 	Final number of discovered degrons: 1
# 		[(477, 493)]
# 		Length of (477, 493): 16
#
#
# Motif: DEG_APCC_TPR_1.tsv.gz
#
# 	Degron discovered in protein ENST00000002165
# 	Initial number of discovered degrons: 2
# 		Length of(70, 79): 9
# 		Length of(72, 81): 9
# 	Final number of discovered degrons: 1
# 		[(70, 81)]
# 		Length of (70, 81): 11
#
# 	Degron discovered in protein ENST00000003084
# 	Initial number of discovered degrons: 6
# 		Length of(79, 88): 9
# 		Length of(242, 251): 9
# 		Length of(1096, 1105): 9
# 		Length of(1097, 1106): 9
# 		Length of(1098, 1107): 9
# 		Length of(1274, 1283): 9
# 	Final number of discovered degrons: 4
# 		[(79, 88), (242, 251), (1096, 1107), (1274, 1283)]
# 		Length of (79, 88): 9
# 		Length of (242, 251): 9
# 		Length of (1096, 1107): 11
# 		Length of (1274, 1283): 9
#
# 	Degron discovered in protein ENST00000003100
# 	Initial number of discovered degrons: 4
# 		Length of(379, 388): 9
# 		Length of(380, 389): 9
# 		Length of(382, 391): 9
# 		Length of(383, 392): 9
# 	Final number of discovered degrons: 1
# 		[(379, 392)]
# 		Length of (379, 392): 13
#
# 	Degron discovered in protein ENST00000009530
# 	Initial number of discovered degrons: 2
# 		Length of(181, 190): 9
# 		Length of(182, 191): 9
# 	Final number of discovered degrons: 1
# 		[(181, 191)]
# 		Length of (181, 191): 10
#
# 	Degron discovered in protein ENST00000040877
# 	Initial number of discovered degrons: 3
# 		Length of(371, 380): 9
# 		Length of(373, 382): 9
# 		Length of(375, 384): 9
# 	Final number of discovered degrons: 1
# 		[(371, 384)]
# 		Length of (371, 384): 13
#
# 	Degron discovered in protein ENST00000168148
# 	Initial number of discovered degrons: 2
# 		Length of(2, 11): 9
# 		Length of(8, 17): 9
# 	Final number of discovered degrons: 1
# 		[(2, 17)]
# 		Length of (2, 17): 15
#
# 	Degron discovered in protein ENST00000181383
# 	Initial number of discovered degrons: 2
# 		Length of(230, 239): 9
# 		Length of(233, 242): 9
# 	Final number of discovered degrons: 1
# 		[(230, 242)]
# 		Length of (230, 242): 12
#
# 	Degron discovered in protein ENST00000182527
# 	Initial number of discovered degrons: 3
# 		Length of(303, 312): 9
# 		Length of(307, 316): 9
# 		Length of(310, 319): 9
# 	Final number of discovered degrons: 1
# 		[(303, 319)]
# 		Length of (303, 319): 16
#
# 	Degron discovered in protein ENST00000203629
# 	Initial number of discovered degrons: 2
# 		Length of(470, 479): 9
# 		Length of(473, 482): 9
# 	Final number of discovered degrons: 1
# 		[(470, 482)]
# 		Length of (470, 482): 12
#
# 	Degron discovered in protein ENST00000203630
# 	Initial number of discovered degrons: 4
# 		Length of(74, 83): 9
# 		Length of(78, 87): 9
# 		Length of(82, 91): 9
# 		Length of(149, 158): 9
# 	Final number of discovered degrons: 2
# 		[(74, 91), (149, 158)]
# 		Length of (74, 91): 17
# 		Length of (149, 158): 9
#
# 	Degron discovered in protein ENST00000209929
# 	Initial number of discovered degrons: 4
# 		Length of(252, 261): 9
# 		Length of(253, 262): 9
# 		Length of(254, 263): 9
# 		Length of(402, 411): 9
# 	Final number of discovered degrons: 2
# 		[(252, 263), (402, 411)]
# 		Length of (252, 263): 11
# 		Length of (402, 411): 9
#
# 	Degron discovered in protein ENST00000216181
# 	Initial number of discovered degrons: 3
# 		Length of(820, 829): 9
# 		Length of(822, 831): 9
# 		Length of(823, 832): 9
# 	Final number of discovered degrons: 1
# 		[(820, 832)]
# 		Length of (820, 832): 12
#
# 	Degron discovered in protein ENST00000216268
# 	Initial number of discovered degrons: 2
# 		Length of(324, 333): 9
# 		Length of(327, 336): 9
# 	Final number of discovered degrons: 1
# 		[(324, 336)]
# 		Length of (324, 336): 12
#
# 	Degron discovered in protein ENST00000216500
# 	Initial number of discovered degrons: 2
# 		Length of(298, 307): 9
# 		Length of(300, 309): 9
# 	Final number of discovered degrons: 1
# 		[(298, 309)]
# 		Length of (298, 309): 11
#
# 	Degron discovered in protein ENST00000217420
# 	Initial number of discovered degrons: 2
# 		Length of(335, 344): 9
# 		Length of(336, 345): 9
# 	Final number of discovered degrons: 1
# 		[(335, 345)]
# 		Length of (335, 345): 10
#
# 	Degron discovered in protein ENST00000217446
# 	Initial number of discovered degrons: 3
# 		Length of(223, 232): 9
# 		Length of(224, 233): 9
# 		Length of(369, 378): 9
# 	Final number of discovered degrons: 2
# 		[(223, 233), (369, 378)]
# 		Length of (223, 233): 10
# 		Length of (369, 378): 9
#
# 	Degron discovered in protein ENST00000219660
# 	Initial number of discovered degrons: 3
# 		Length of(24, 33): 9
# 		Length of(222, 231): 9
# 		Length of(224, 233): 9
# 	Final number of discovered degrons: 2
# 		[(24, 33), (222, 233)]
# 		Length of (24, 33): 9
# 		Length of (222, 233): 11
#
# 	Degron discovered in protein ENST00000219746
# 	Initial number of discovered degrons: 3
# 		Length of(465, 474): 9
# 		Length of(468, 477): 9
# 		Length of(469, 478): 9
# 	Final number of discovered degrons: 1
# 		[(465, 478)]
# 		Length of (465, 478): 13
#
# 	Degron discovered in protein ENST00000221265
# 	Initial number of discovered degrons: 2
# 		Length of(238, 247): 9
# 		Length of(241, 250): 9
# 	Final number of discovered degrons: 1
# 		[(238, 250)]
# 		Length of (238, 250): 12
#
# 	Degron discovered in protein ENST00000222002
# 	Initial number of discovered degrons: 2
# 		Length of(162, 171): 9
# 		Length of(163, 172): 9
# 	Final number of discovered degrons: 1
# 		[(162, 172)]
# 		Length of (162, 172): 10
#
# 	Degron discovered in protein ENST00000222115
# 	Initial number of discovered degrons: 2
# 		Length of(392, 401): 9
# 		Length of(393, 402): 9
# 	Final number of discovered degrons: 1
# 		[(392, 402)]
# 		Length of (392, 402): 10
#
# 	Degron discovered in protein ENST00000222584
# 	Initial number of discovered degrons: 2
# 		Length of(674, 683): 9
# 		Length of(678, 687): 9
# 	Final number of discovered degrons: 1
# 		[(674, 687)]
# 		Length of (674, 687): 13
#
# 	Degron discovered in protein ENST00000223026
# 	Initial number of discovered degrons: 3
# 		Length of(144, 153): 9
# 		Length of(146, 155): 9
# 		Length of(278, 287): 9
# 	Final number of discovered degrons: 2
# 		[(144, 155), (278, 287)]
# 		Length of (144, 155): 11
# 		Length of (278, 287): 9
#
# 	Degron discovered in protein ENST00000225430
# 	Initial number of discovered degrons: 3
# 		Length of(91, 100): 9
# 		Length of(94, 103): 9
# 		Length of(95, 104): 9
# 	Final number of discovered degrons: 1
# 		[(91, 104)]
# 		Length of (91, 104): 13
#
# 	Degron discovered in protein ENST00000225927
# 	Initial number of discovered degrons: 4
# 		Length of(140, 149): 9
# 		Length of(143, 152): 9
# 		Length of(154, 163): 9
# 		Length of(524, 533): 9
# 	Final number of discovered degrons: 3
# 		[(140, 152), (154, 163), (524, 533)]
# 		Length of (140, 152): 12
# 		Length of (154, 163): 9
# 		Length of (524, 533): 9
#
# 	Degron discovered in protein ENST00000226432
# 	Initial number of discovered degrons: 2
# 		Length of(609, 618): 9
# 		Length of(613, 622): 9
# 	Final number of discovered degrons: 1
# 		[(609, 622)]
# 		Length of (609, 622): 13
#
# 	Degron discovered in protein ENST00000228027
# 	Initial number of discovered degrons: 2
# 		Length of(125, 134): 9
# 		Length of(128, 137): 9
# 	Final number of discovered degrons: 1
# 		[(125, 137)]
# 		Length of (125, 137): 12
#
# 	Degron discovered in protein ENST00000228318
# 	Initial number of discovered degrons: 2
# 		Length of(223, 232): 9
# 		Length of(224, 233): 9
# 	Final number of discovered degrons: 1
# 		[(223, 233)]
# 		Length of (223, 233): 10
#
# 	Degron discovered in protein ENST00000229795
# 	Initial number of discovered degrons: 2
# 		Length of(190, 199): 9
# 		Length of(194, 203): 9
# 	Final number of discovered degrons: 1
# 		[(190, 203)]
# 		Length of (190, 203): 13
#
# 	Degron discovered in protein ENST00000232892
# 	Initial number of discovered degrons: 4
# 		Length of(28, 37): 9
# 		Length of(29, 38): 9
# 		Length of(30, 39): 9
# 		Length of(31, 40): 9
# 	Final number of discovered degrons: 1
# 		[(28, 40)]
# 		Length of (28, 40): 12
#
# 	Degron discovered in protein ENST00000233712
# 	Initial number of discovered degrons: 2
# 		Length of(126, 135): 9
# 		Length of(131, 140): 9
# 	Final number of discovered degrons: 1
# 		[(126, 140)]
# 		Length of (126, 140): 14
#
# 	Degron discovered in protein ENST00000233826
# 	Initial number of discovered degrons: 5
# 		Length of(45, 54): 9
# 		Length of(47, 56): 9
# 		Length of(48, 57): 9
# 		Length of(49, 58): 9
# 		Length of(51, 60): 9
# 	Final number of discovered degrons: 1
# 		[(45, 60)]
# 		Length of (45, 60): 15
#
# 	Degron discovered in protein ENST00000234739
# 	Initial number of discovered degrons: 6
# 		Length of(729, 738): 9
# 		Length of(1268, 1277): 9
# 		Length of(1308, 1317): 9
# 		Length of(1379, 1388): 9
# 		Length of(1380, 1389): 9
# 		Length of(1392, 1401): 9
# 	Final number of discovered degrons: 5
# 		[(729, 738), (1268, 1277), (1308, 1317), (1379, 1389), (1392, 1401)]
# 		Length of (729, 738): 9
# 		Length of (1268, 1277): 9
# 		Length of (1308, 1317): 9
# 		Length of (1379, 1389): 10
# 		Length of (1392, 1401): 9
#
# 	Degron discovered in protein ENST00000234816
# 	Initial number of discovered degrons: 2
# 		Length of(407, 416): 9
# 		Length of(408, 417): 9
# 	Final number of discovered degrons: 1
# 		[(407, 417)]
# 		Length of (407, 417): 10
#
# 	Degron discovered in protein ENST00000236192
# 	Initial number of discovered degrons: 2
# 		Length of(103, 112): 9
# 		Length of(106, 115): 9
# 	Final number of discovered degrons: 1
# 		[(103, 115)]
# 		Length of (103, 115): 12
#
# 	Degron discovered in protein ENST00000237172
# 	Initial number of discovered degrons: 2
# 		Length of(865, 874): 9
# 		Length of(867, 876): 9
# 	Final number of discovered degrons: 1
# 		[(865, 876)]
# 		Length of (865, 876): 11
#
# 	Degron discovered in protein ENST00000238256
# 	Initial number of discovered degrons: 3
# 		Length of(560, 569): 9
# 		Length of(563, 572): 9
# 		Length of(890, 899): 9
# 	Final number of discovered degrons: 2
# 		[(560, 572), (890, 899)]
# 		Length of (560, 572): 12
# 		Length of (890, 899): 9
#
# 	Degron discovered in protein ENST00000240123
# 	Initial number of discovered degrons: 2
# 		Length of(146, 155): 9
# 		Length of(147, 156): 9
# 	Final number of discovered degrons: 1
# 		[(146, 156)]
# 		Length of (146, 156): 10
#
# 	Degron discovered in protein ENST00000240662
# 	Initial number of discovered degrons: 2
# 		Length of(384, 393): 9
# 		Length of(390, 399): 9
# 	Final number of discovered degrons: 1
# 		[(384, 399)]
# 		Length of (384, 399): 15
#
# 	Degron discovered in protein ENST00000245615
# 	Initial number of discovered degrons: 3
# 		Length of(314, 323): 9
# 		Length of(319, 328): 9
# 		Length of(396, 405): 9
# 	Final number of discovered degrons: 2
# 		[(314, 328), (396, 405)]
# 		Length of (314, 328): 14
# 		Length of (396, 405): 9
#
# 	Degron discovered in protein ENST00000246794
# 	Initial number of discovered degrons: 2
# 		Length of(129, 138): 9
# 		Length of(132, 141): 9
# 	Final number of discovered degrons: 1
# 		[(129, 141)]
# 		Length of (129, 141): 12
#
# 	Degron discovered in protein ENST00000246801
# 	Initial number of discovered degrons: 2
# 		Length of(59, 68): 9
# 		Length of(61, 70): 9
# 	Final number of discovered degrons: 1
# 		[(59, 70)]
# 		Length of (59, 70): 11
#
# 	Degron discovered in protein ENST00000247001
# 	Initial number of discovered degrons: 4
# 		Length of(450, 459): 9
# 		Length of(451, 460): 9
# 		Length of(454, 463): 9
# 		Length of(567, 576): 9
# 	Final number of discovered degrons: 2
# 		[(450, 463), (567, 576)]
# 		Length of (450, 463): 13
# 		Length of (567, 576): 9
#
# 	Degron discovered in protein ENST00000248594
# 	Initial number of discovered degrons: 2
# 		Length of(115, 124): 9
# 		Length of(116, 125): 9
# 	Final number of discovered degrons: 1
# 		[(115, 125)]
# 		Length of (115, 125): 10
#
# 	Degron discovered in protein ENST00000249075
# 	Initial number of discovered degrons: 2
# 		Length of(36, 45): 9
# 		Length of(40, 49): 9
# 	Final number of discovered degrons: 1
# 		[(36, 49)]
# 		Length of (36, 49): 13
#
# 	Degron discovered in protein ENST00000249079
# 	Initial number of discovered degrons: 3
# 		Length of(42, 51): 9
# 		Length of(45, 54): 9
# 		Length of(47, 56): 9
# 	Final number of discovered degrons: 1
# 		[(42, 56)]
# 		Length of (42, 56): 14
#
# 	Degron discovered in protein ENST00000251241
# 	Initial number of discovered degrons: 3
# 		Length of(570, 579): 9
# 		Length of(572, 581): 9
# 		Length of(575, 584): 9
# 	Final number of discovered degrons: 1
# 		[(570, 584)]
# 		Length of (570, 584): 14
#
# 	Degron discovered in protein ENST00000252050
# 	Initial number of discovered degrons: 3
# 		Length of(427, 436): 9
# 		Length of(1268, 1277): 9
# 		Length of(1271, 1280): 9
# 	Final number of discovered degrons: 2
# 		[(427, 436), (1268, 1280)]
# 		Length of (427, 436): 9
# 		Length of (1268, 1280): 12
#
# 	Degron discovered in protein ENST00000252242
# 	Initial number of discovered degrons: 3
# 		Length of(385, 394): 9
# 		Length of(386, 395): 9
# 		Length of(388, 397): 9
# 	Final number of discovered degrons: 1
# 		[(385, 397)]
# 		Length of (385, 397): 12
#
# 	Degron discovered in protein ENST00000252245
# 	Initial number of discovered degrons: 3
# 		Length of(366, 375): 9
# 		Length of(367, 376): 9
# 		Length of(369, 378): 9
# 	Final number of discovered degrons: 1
# 		[(366, 378)]
# 		Length of (366, 378): 12
#
# 	Degron discovered in protein ENST00000252590
# 	Initial number of discovered degrons: 3
# 		Length of(97, 106): 9
# 		Length of(98, 107): 9
# 		Length of(114, 123): 9
# 	Final number of discovered degrons: 2
# 		[(97, 107), (114, 123)]
# 		Length of (97, 107): 10
# 		Length of (114, 123): 9
#
# 	Degron discovered in protein ENST00000253063
# 	Initial number of discovered degrons: 3
# 		Length of(435, 444): 9
# 		Length of(436, 445): 9
# 		Length of(439, 448): 9
# 	Final number of discovered degrons: 1
# 		[(435, 448)]
# 		Length of (435, 448): 13
#
# 	Degron discovered in protein ENST00000253237
# 	Initial number of discovered degrons: 2
# 		Length of(101, 110): 9
# 		Length of(104, 113): 9
# 	Final number of discovered degrons: 1
# 		[(101, 113)]
# 		Length of (101, 113): 12
#
# 	Degron discovered in protein ENST00000253255
# 	Initial number of discovered degrons: 4
# 		Length of(867, 876): 9
# 		Length of(1367, 1376): 9
# 		Length of(1423, 1432): 9
# 		Length of(1424, 1433): 9
# 	Final number of discovered degrons: 3
# 		[(867, 876), (1367, 1376), (1423, 1433)]
# 		Length of (867, 876): 9
# 		Length of (1367, 1376): 9
# 		Length of (1423, 1433): 10
#
# 	Degron discovered in protein ENST00000254337
# 	Initial number of discovered degrons: 5
# 		Length of(102, 111): 9
# 		Length of(163, 172): 9
# 		Length of(164, 173): 9
# 		Length of(166, 175): 9
# 		Length of(169, 178): 9
# 	Final number of discovered degrons: 2
# 		[(102, 111), (163, 178)]
# 		Length of (102, 111): 9
# 		Length of (163, 178): 15
#
# 	Degron discovered in protein ENST00000254488
# 	Initial number of discovered degrons: 2
# 		Length of(511, 520): 9
# 		Length of(515, 524): 9
# 	Final number of discovered degrons: 1
# 		[(511, 524)]
# 		Length of (511, 524): 13
#
# 	Degron discovered in protein ENST00000254667
# 	Initial number of discovered degrons: 4
# 		Length of(251, 260): 9
# 		Length of(435, 444): 9
# 		Length of(508, 517): 9
# 		Length of(509, 518): 9
# 	Final number of discovered degrons: 3
# 		[(251, 260), (435, 444), (508, 518)]
# 		Length of (251, 260): 9
# 		Length of (435, 444): 9
# 		Length of (508, 518): 10
#
# 	Degron discovered in protein ENST00000254730
# 	Initial number of discovered degrons: 2
# 		Length of(267, 276): 9
# 		Length of(269, 278): 9
# 	Final number of discovered degrons: 1
# 		[(267, 278)]
# 		Length of (267, 278): 11
#
# 	Degron discovered in protein ENST00000255078
# 	Initial number of discovered degrons: 2
# 		Length of(440, 449): 9
# 		Length of(441, 450): 9
# 	Final number of discovered degrons: 1
# 		[(440, 450)]
# 		Length of (440, 450): 10
#
# 	Degron discovered in protein ENST00000255262
# 	Initial number of discovered degrons: 2
# 		Length of(207, 216): 9
# 		Length of(208, 217): 9
# 	Final number of discovered degrons: 1
# 		[(207, 217)]
# 		Length of (207, 217): 10
#
# 	Degron discovered in protein ENST00000256343
# 	Initial number of discovered degrons: 3
# 		Length of(88, 97): 9
# 		Length of(1085, 1094): 9
# 		Length of(1086, 1095): 9
# 	Final number of discovered degrons: 2
# 		[(88, 97), (1085, 1095)]
# 		Length of (88, 97): 9
# 		Length of (1085, 1095): 10
#
# 	Degron discovered in protein ENST00000256737
# 	Initial number of discovered degrons: 4
# 		Length of(254, 263): 9
# 		Length of(366, 375): 9
# 		Length of(367, 376): 9
# 		Length of(583, 592): 9
# 	Final number of discovered degrons: 3
# 		[(254, 263), (366, 376), (583, 592)]
# 		Length of (254, 263): 9
# 		Length of (366, 376): 10
# 		Length of (583, 592): 9
#
# 	Degron discovered in protein ENST00000256854
# 	Initial number of discovered degrons: 5
# 		Length of(63, 72): 9
# 		Length of(66, 75): 9
# 		Length of(229, 238): 9
# 		Length of(232, 241): 9
# 		Length of(248, 257): 9
# 	Final number of discovered degrons: 3
# 		[(63, 75), (229, 241), (248, 257)]
# 		Length of (63, 75): 12
# 		Length of (229, 241): 12
# 		Length of (248, 257): 9
#
# 	Degron discovered in protein ENST00000256935
# 	Initial number of discovered degrons: 5
# 		Length of(50, 59): 9
# 		Length of(112, 121): 9
# 		Length of(117, 126): 9
# 		Length of(908, 917): 9
# 		Length of(989, 998): 9
# 	Final number of discovered degrons: 4
# 		[(50, 59), (112, 126), (908, 917), (989, 998)]
# 		Length of (50, 59): 9
# 		Length of (112, 126): 14
# 		Length of (908, 917): 9
# 		Length of (989, 998): 9
#
# 	Degron discovered in protein ENST00000256958
# 	Initial number of discovered degrons: 3
# 		Length of(49, 58): 9
# 		Length of(167, 176): 9
# 		Length of(172, 181): 9
# 	Final number of discovered degrons: 2
# 		[(49, 58), (167, 181)]
# 		Length of (49, 58): 9
# 		Length of (167, 181): 14
#
# 	Degron discovered in protein ENST00000257414
# 	Initial number of discovered degrons: 3
# 		Length of(56, 65): 9
# 		Length of(58, 67): 9
# 		Length of(485, 494): 9
# 	Final number of discovered degrons: 2
# 		[(56, 67), (485, 494)]
# 		Length of (56, 67): 11
# 		Length of (485, 494): 9
#
# 	Degron discovered in protein ENST00000257600
# 	Initial number of discovered degrons: 3
# 		Length of(152, 161): 9
# 		Length of(156, 165): 9
# 		Length of(158, 167): 9
# 	Final number of discovered degrons: 1
# 		[(152, 167)]
# 		Length of (152, 167): 15
#
# 	Degron discovered in protein ENST00000258787
# 	Initial number of discovered degrons: 3
# 		Length of(735, 744): 9
# 		Length of(736, 745): 9
# 		Length of(900, 909): 9
# 	Final number of discovered degrons: 2
# 		[(735, 745), (900, 909)]
# 		Length of (735, 745): 10
# 		Length of (900, 909): 9
#
# 	Degron discovered in protein ENST00000259324
# 	Initial number of discovered degrons: 4
# 		Length of(334, 343): 9
# 		Length of(335, 344): 9
# 		Length of(336, 345): 9
# 		Length of(337, 346): 9
# 	Final number of discovered degrons: 1
# 		[(334, 346)]
# 		Length of (334, 346): 12
#
# 	Degron discovered in protein ENST00000260010
# 	Initial number of discovered degrons: 4
# 		Length of(614, 623): 9
# 		Length of(615, 624): 9
# 		Length of(616, 625): 9
# 		Length of(617, 626): 9
# 	Final number of discovered degrons: 1
# 		[(614, 626)]
# 		Length of (614, 626): 12
#
# 	Degron discovered in protein ENST00000260324
# 	Initial number of discovered degrons: 3
# 		Length of(421, 430): 9
# 		Length of(422, 431): 9
# 		Length of(426, 435): 9
# 	Final number of discovered degrons: 1
# 		[(421, 435)]
# 		Length of (421, 435): 14
#
# 	Degron discovered in protein ENST00000260408
# 	Initial number of discovered degrons: 2
# 		Length of(738, 747): 9
# 		Length of(739, 748): 9
# 	Final number of discovered degrons: 1
# 		[(738, 748)]
# 		Length of (738, 748): 10
#
# 	Degron discovered in protein ENST00000261196
# 	Initial number of discovered degrons: 2
# 		Length of(167, 176): 9
# 		Length of(172, 181): 9
# 	Final number of discovered degrons: 1
# 		[(167, 181)]
# 		Length of (167, 181): 14
#
# 	Degron discovered in protein ENST00000261383
# 	Initial number of discovered degrons: 7
# 		Length of(480, 489): 9
# 		Length of(1250, 1259): 9
# 		Length of(1691, 1700): 9
# 		Length of(2300, 2309): 9
# 		Length of(3703, 3712): 9
# 		Length of(3704, 3713): 9
# 		Length of(3705, 3714): 9
# 	Final number of discovered degrons: 5
# 		[(480, 489), (1250, 1259), (1691, 1700), (2300, 2309), (3703, 3714)]
# 		Length of (480, 489): 9
# 		Length of (1250, 1259): 9
# 		Length of (1691, 1700): 9
# 		Length of (2300, 2309): 9
# 		Length of (3703, 3714): 11
#
# 	Degron discovered in protein ENST00000261407
# 	Initial number of discovered degrons: 2
# 		Length of(266, 275): 9
# 		Length of(267, 276): 9
# 	Final number of discovered degrons: 1
# 		[(266, 276)]
# 		Length of (266, 276): 10
#
# 	Degron discovered in protein ENST00000261534
# 	Initial number of discovered degrons: 3
# 		Length of(136, 145): 9
# 		Length of(139, 148): 9
# 		Length of(569, 578): 9
# 	Final number of discovered degrons: 2
# 		[(136, 148), (569, 578)]
# 		Length of (136, 148): 12
# 		Length of (569, 578): 9
#
# 	Degron discovered in protein ENST00000261596
# 	Initial number of discovered degrons: 2
# 		Length of(553, 562): 9
# 		Length of(558, 567): 9
# 	Final number of discovered degrons: 1
# 		[(553, 567)]
# 		Length of (553, 567): 14
#
# 	Degron discovered in protein ENST00000261797
# 	Initial number of discovered degrons: 6
# 		Length of(382, 391): 9
# 		Length of(384, 393): 9
# 		Length of(385, 394): 9
# 		Length of(386, 395): 9
# 		Length of(391, 400): 9
# 		Length of(470, 479): 9
# 	Final number of discovered degrons: 2
# 		[(382, 400), (470, 479)]
# 		Length of (382, 400): 18
# 		Length of (470, 479): 9
#
# 	Degron discovered in protein ENST00000262013
# 	Initial number of discovered degrons: 2
# 		Length of(163, 172): 9
# 		Length of(167, 176): 9
# 	Final number of discovered degrons: 1
# 		[(163, 176)]
# 		Length of (163, 176): 13
#
# 	Degron discovered in protein ENST00000262065
# 	Initial number of discovered degrons: 3
# 		Length of(5, 14): 9
# 		Length of(124, 133): 9
# 		Length of(127, 136): 9
# 	Final number of discovered degrons: 2
# 		[(5, 14), (124, 136)]
# 		Length of (5, 14): 9
# 		Length of (124, 136): 12
#
# 	Degron discovered in protein ENST00000262207
# 	Initial number of discovered degrons: 2
# 		Length of(186, 195): 9
# 		Length of(187, 196): 9
# 	Final number of discovered degrons: 1
# 		[(186, 196)]
# 		Length of (186, 196): 10
#
# 	Degron discovered in protein ENST00000262213
# 	Initial number of discovered degrons: 4
# 		Length of(153, 162): 9
# 		Length of(308, 317): 9
# 		Length of(313, 322): 9
# 		Length of(315, 324): 9
# 	Final number of discovered degrons: 2
# 		[(153, 162), (308, 324)]
# 		Length of (153, 162): 9
# 		Length of (308, 324): 16
#
# 	Degron discovered in protein ENST00000262265
# 	Initial number of discovered degrons: 3
# 		Length of(161, 170): 9
# 		Length of(162, 171): 9
# 		Length of(171, 180): 9
# 	Final number of discovered degrons: 2
# 		[(161, 171), (171, 180)]
# 		Length of (161, 171): 10
# 		Length of (171, 180): 9
#
# 	Degron discovered in protein ENST00000262441
# 	Initial number of discovered degrons: 3
# 		Length of(335, 344): 9
# 		Length of(338, 347): 9
# 		Length of(339, 348): 9
# 	Final number of discovered degrons: 1
# 		[(335, 348)]
# 		Length of (335, 348): 13
#
# 	Degron discovered in protein ENST00000262450
# 	Initial number of discovered degrons: 3
# 		Length of(587, 596): 9
# 		Length of(589, 598): 9
# 		Length of(590, 599): 9
# 	Final number of discovered degrons: 1
# 		[(587, 599)]
# 		Length of (587, 599): 12
#
# 	Degron discovered in protein ENST00000262455
# 	Initial number of discovered degrons: 2
# 		Length of(115, 124): 9
# 		Length of(118, 127): 9
# 	Final number of discovered degrons: 1
# 		[(115, 127)]
# 		Length of (115, 127): 12
#
# 	Degron discovered in protein ENST00000263087
# 	Initial number of discovered degrons: 3
# 		Length of(224, 233): 9
# 		Length of(225, 234): 9
# 		Length of(613, 622): 9
# 	Final number of discovered degrons: 2
# 		[(224, 234), (613, 622)]
# 		Length of (224, 234): 10
# 		Length of (613, 622): 9
#
# 	Degron discovered in protein ENST00000263125
# 	Initial number of discovered degrons: 3
# 		Length of(626, 635): 9
# 		Length of(682, 691): 9
# 		Length of(683, 692): 9
# 	Final number of discovered degrons: 2
# 		[(626, 635), (682, 692)]
# 		Length of (626, 635): 9
# 		Length of (682, 692): 10
#
# 	Degron discovered in protein ENST00000263245
# 	Initial number of discovered degrons: 2
# 		Length of(68, 77): 9
# 		Length of(71, 80): 9
# 	Final number of discovered degrons: 1
# 		[(68, 80)]
# 		Length of (68, 80): 12
#
# 	Degron discovered in protein ENST00000263253
# 	Initial number of discovered degrons: 9
# 		Length of(399, 408): 9
# 		Length of(2167, 2176): 9
# 		Length of(2223, 2232): 9
# 		Length of(2224, 2233): 9
# 		Length of(2225, 2234): 9
# 		Length of(2226, 2235): 9
# 		Length of(2227, 2236): 9
# 		Length of(2230, 2239): 9
# 		Length of(2231, 2240): 9
# 	Final number of discovered degrons: 3
# 		[(399, 408), (2167, 2176), (2223, 2240)]
# 		Length of (399, 408): 9
# 		Length of (2167, 2176): 9
# 		Length of (2223, 2240): 17
#
# 	Degron discovered in protein ENST00000263372
# 	Initial number of discovered degrons: 2
# 		Length of(154, 163): 9
# 		Length of(157, 166): 9
# 	Final number of discovered degrons: 1
# 		[(154, 166)]
# 		Length of (154, 166): 12
#
# 	Degron discovered in protein ENST00000263736
# 	Initial number of discovered degrons: 3
# 		Length of(428, 437): 9
# 		Length of(462, 471): 9
# 		Length of(463, 472): 9
# 	Final number of discovered degrons: 2
# 		[(428, 437), (462, 472)]
# 		Length of (428, 437): 9
# 		Length of (462, 472): 10
#
# 	Degron discovered in protein ENST00000263817
# 	Initial number of discovered degrons: 4
# 		Length of(175, 184): 9
# 		Length of(182, 191): 9
# 		Length of(308, 317): 9
# 		Length of(486, 495): 9
# 	Final number of discovered degrons: 3
# 		[(175, 191), (308, 317), (486, 495)]
# 		Length of (175, 191): 16
# 		Length of (308, 317): 9
# 		Length of (486, 495): 9
#
# 	Degron discovered in protein ENST00000263946
# 	Initial number of discovered degrons: 2
# 		Length of(680, 689): 9
# 		Length of(684, 693): 9
# 	Final number of discovered degrons: 1
# 		[(680, 693)]
# 		Length of (680, 693): 13
#
# 	Degron discovered in protein ENST00000263967
# 	Initial number of discovered degrons: 4
# 		Length of(273, 282): 9
# 		Length of(732, 741): 9
# 		Length of(815, 824): 9
# 		Length of(816, 825): 9
# 	Final number of discovered degrons: 3
# 		[(273, 282), (732, 741), (815, 825)]
# 		Length of (273, 282): 9
# 		Length of (732, 741): 9
# 		Length of (815, 825): 10
#
# 	Degron discovered in protein ENST00000264027
# 	Initial number of discovered degrons: 2
# 		Length of(130, 139): 9
# 		Length of(133, 142): 9
# 	Final number of discovered degrons: 1
# 		[(130, 142)]
# 		Length of (130, 142): 12
#
# 	Degron discovered in protein ENST00000264042
# 	Initial number of discovered degrons: 2
# 		Length of(101, 110): 9
# 		Length of(102, 111): 9
# 	Final number of discovered degrons: 1
# 		[(101, 111)]
# 		Length of (101, 111): 10
#
# 	Degron discovered in protein ENST00000264228
# 	Initial number of discovered degrons: 3
# 		Length of(199, 208): 9
# 		Length of(200, 209): 9
# 		Length of(203, 212): 9
# 	Final number of discovered degrons: 1
# 		[(199, 212)]
# 		Length of (199, 212): 13
#
# 	Degron discovered in protein ENST00000264331
# 	Initial number of discovered degrons: 2
# 		Length of(211, 220): 9
# 		Length of(212, 221): 9
# 	Final number of discovered degrons: 1
# 		[(211, 221)]
# 		Length of (211, 221): 10
#
# 	Degron discovered in protein ENST00000264363
# 	Initial number of discovered degrons: 5
# 		Length of(372, 381): 9
# 		Length of(374, 383): 9
# 		Length of(375, 384): 9
# 		Length of(376, 385): 9
# 		Length of(381, 390): 9
# 	Final number of discovered degrons: 1
# 		[(372, 390)]
# 		Length of (372, 390): 18
#
# 	Degron discovered in protein ENST00000264381
# 	Initial number of discovered degrons: 2
# 		Length of(574, 583): 9
# 		Length of(576, 585): 9
# 	Final number of discovered degrons: 1
# 		[(574, 585)]
# 		Length of (574, 585): 11
#
# 	Degron discovered in protein ENST00000264463
# 	Initial number of discovered degrons: 2
# 		Length of(48, 57): 9
# 		Length of(53, 62): 9
# 	Final number of discovered degrons: 1
# 		[(48, 62)]
# 		Length of (48, 62): 14
#
# 	Degron discovered in protein ENST00000264497
# 	Initial number of discovered degrons: 2
# 		Length of(31, 40): 9
# 		Length of(35, 44): 9
# 	Final number of discovered degrons: 1
# 		[(31, 44)]
# 		Length of (31, 44): 13
#
# 	Degron discovered in protein ENST00000264735
# 	Initial number of discovered degrons: 3
# 		Length of(39, 48): 9
# 		Length of(40, 49): 9
# 		Length of(41, 50): 9
# 	Final number of discovered degrons: 1
# 		[(39, 50)]
# 		Length of (39, 50): 11
#
# 	Degron discovered in protein ENST00000264956
# 	Initial number of discovered degrons: 4
# 		Length of(231, 240): 9
# 		Length of(234, 243): 9
# 		Length of(688, 697): 9
# 		Length of(864, 873): 9
# 	Final number of discovered degrons: 3
# 		[(231, 243), (688, 697), (864, 873)]
# 		Length of (231, 243): 12
# 		Length of (688, 697): 9
# 		Length of (864, 873): 9
#
# 	Degron discovered in protein ENST00000265069
# 	Initial number of discovered degrons: 2
# 		Length of(651, 660): 9
# 		Length of(653, 662): 9
# 	Final number of discovered degrons: 1
# 		[(651, 662)]
# 		Length of (651, 662): 11
#
# 	Degron discovered in protein ENST00000265071
# 	Initial number of discovered degrons: 2
# 		Length of(52, 61): 9
# 		Length of(53, 62): 9
# 	Final number of discovered degrons: 1
# 		[(52, 62)]
# 		Length of (52, 62): 10
#
# 	Degron discovered in protein ENST00000265080
# 	Initial number of discovered degrons: 3
# 		Length of(213, 222): 9
# 		Length of(1181, 1190): 9
# 		Length of(1184, 1193): 9
# 	Final number of discovered degrons: 2
# 		[(213, 222), (1181, 1193)]
# 		Length of (213, 222): 9
# 		Length of (1181, 1193): 12
#
# 	Degron discovered in protein ENST00000265162
# 	Initial number of discovered degrons: 3
# 		Length of(863, 872): 9
# 		Length of(866, 875): 9
# 		Length of(868, 877): 9
# 	Final number of discovered degrons: 1
# 		[(863, 877)]
# 		Length of (863, 877): 14
#
# 	Degron discovered in protein ENST00000265316
# 	Initial number of discovered degrons: 3
# 		Length of(166, 175): 9
# 		Length of(168, 177): 9
# 		Length of(356, 365): 9
# 	Final number of discovered degrons: 2
# 		[(166, 177), (356, 365)]
# 		Length of (166, 177): 11
# 		Length of (356, 365): 9
#
# 	Degron discovered in protein ENST00000265433
# 	Initial number of discovered degrons: 2
# 		Length of(290, 299): 9
# 		Length of(294, 303): 9
# 	Final number of discovered degrons: 1
# 		[(290, 303)]
# 		Length of (290, 303): 13
#
# 	Degron discovered in protein ENST00000265825
# 	Initial number of discovered degrons: 2
# 		Length of(337, 346): 9
# 		Length of(338, 347): 9
# 	Final number of discovered degrons: 1
# 		[(337, 347)]
# 		Length of (337, 347): 10
#
# 	Degron discovered in protein ENST00000265909
# 	Initial number of discovered degrons: 2
# 		Length of(101, 110): 9
# 		Length of(102, 111): 9
# 	Final number of discovered degrons: 1
# 		[(101, 111)]
# 		Length of (101, 111): 10
#
# 	Degron discovered in protein ENST00000265922
# 	Initial number of discovered degrons: 3
# 		Length of(538, 547): 9
# 		Length of(543, 552): 9
# 		Length of(544, 553): 9
# 	Final number of discovered degrons: 1
# 		[(538, 553)]
# 		Length of (538, 553): 15
#
# 	Degron discovered in protein ENST00000265969
# 	Initial number of discovered degrons: 3
# 		Length of(104, 113): 9
# 		Length of(168, 177): 9
# 		Length of(169, 178): 9
# 	Final number of discovered degrons: 2
# 		[(104, 113), (168, 178)]
# 		Length of (104, 113): 9
# 		Length of (168, 178): 10
#
# 	Degron discovered in protein ENST00000266037
# 	Initial number of discovered degrons: 7
# 		Length of(352, 361): 9
# 		Length of(353, 362): 9
# 		Length of(412, 421): 9
# 		Length of(995, 1004): 9
# 		Length of(1110, 1119): 9
# 		Length of(1118, 1127): 9
# 		Length of(1614, 1623): 9
# 	Final number of discovered degrons: 5
# 		[(352, 362), (412, 421), (995, 1004), (1110, 1127), (1614, 1623)]
# 		Length of (352, 362): 10
# 		Length of (412, 421): 9
# 		Length of (995, 1004): 9
# 		Length of (1110, 1127): 17
# 		Length of (1614, 1623): 9
#
# 	Degron discovered in protein ENST00000266604
# 	Initial number of discovered degrons: 4
# 		Length of(5, 14): 9
# 		Length of(91, 100): 9
# 		Length of(93, 102): 9
# 		Length of(95, 104): 9
# 	Final number of discovered degrons: 2
# 		[(5, 14), (91, 104)]
# 		Length of (5, 14): 9
# 		Length of (91, 104): 13
#
# 	Degron discovered in protein ENST00000267101
# 	Initial number of discovered degrons: 3
# 		Length of(666, 675): 9
# 		Length of(941, 950): 9
# 		Length of(946, 955): 9
# 	Final number of discovered degrons: 2
# 		[(666, 675), (941, 955)]
# 		Length of (666, 675): 9
# 		Length of (941, 955): 14
#
# 	Degron discovered in protein ENST00000267163
# 	Initial number of discovered degrons: 2
# 		Length of(700, 709): 9
# 		Length of(703, 712): 9
# 	Final number of discovered degrons: 1
# 		[(700, 712)]
# 		Length of (700, 712): 12
#
# 	Degron discovered in protein ENST00000267199
# 	Initial number of discovered degrons: 2
# 		Length of(202, 211): 9
# 		Length of(205, 214): 9
# 	Final number of discovered degrons: 1
# 		[(202, 214)]
# 		Length of (202, 214): 12
#
# 	Degron discovered in protein ENST00000267750
# 	Initial number of discovered degrons: 2
# 		Length of(99, 108): 9
# 		Length of(100, 109): 9
# 	Final number of discovered degrons: 1
# 		[(99, 109)]
# 		Length of (99, 109): 10
#
# 	Degron discovered in protein ENST00000267889
# 	Initial number of discovered degrons: 3
# 		Length of(308, 317): 9
# 		Length of(700, 709): 9
# 		Length of(702, 711): 9
# 	Final number of discovered degrons: 2
# 		[(308, 317), (700, 711)]
# 		Length of (308, 317): 9
# 		Length of (700, 711): 11
#
# 	Degron discovered in protein ENST00000268070
# 	Initial number of discovered degrons: 3
# 		Length of(260, 269): 9
# 		Length of(1068, 1077): 9
# 		Length of(1072, 1081): 9
# 	Final number of discovered degrons: 2
# 		[(260, 269), (1068, 1081)]
# 		Length of (260, 269): 9
# 		Length of (1068, 1081): 13
#
# 	Degron discovered in protein ENST00000268919
# 	Initial number of discovered degrons: 2
# 		Length of(186, 195): 9
# 		Length of(187, 196): 9
# 	Final number of discovered degrons: 1
# 		[(186, 196)]
# 		Length of (186, 196): 10
#
# 	Degron discovered in protein ENST00000269202
# 	Initial number of discovered degrons: 3
# 		Length of(426, 435): 9
# 		Length of(429, 438): 9
# 		Length of(633, 642): 9
# 	Final number of discovered degrons: 2
# 		[(426, 438), (633, 642)]
# 		Length of (426, 438): 12
# 		Length of (633, 642): 9
#
# 	Degron discovered in protein ENST00000269973
# 	Initial number of discovered degrons: 2
# 		Length of(103, 112): 9
# 		Length of(104, 113): 9
# 	Final number of discovered degrons: 1
# 		[(103, 113)]
# 		Length of (103, 113): 10
#
# 	Degron discovered in protein ENST00000273067
# 	Initial number of discovered degrons: 3
# 		Length of(10, 19): 9
# 		Length of(11, 20): 9
# 		Length of(194, 203): 9
# 	Final number of discovered degrons: 2
# 		[(10, 20), (194, 203)]
# 		Length of (10, 20): 10
# 		Length of (194, 203): 9
#
# 	Degron discovered in protein ENST00000273320
# 	Initial number of discovered degrons: 2
# 		Length of(252, 261): 9
# 		Length of(256, 265): 9
# 	Final number of discovered degrons: 1
# 		[(252, 265)]
# 		Length of (252, 265): 13
#
# 	Degron discovered in protein ENST00000274643
# 	Initial number of discovered degrons: 2
# 		Length of(214, 223): 9
# 		Length of(215, 224): 9
# 	Final number of discovered degrons: 1
# 		[(214, 224)]
# 		Length of (214, 224): 10
#
# 	Degron discovered in protein ENST00000276440
# 	Initial number of discovered degrons: 2
# 		Length of(1004, 1013): 9
# 		Length of(1006, 1015): 9
# 	Final number of discovered degrons: 1
# 		[(1004, 1015)]
# 		Length of (1004, 1015): 11
#
# 	Degron discovered in protein ENST00000276616
# 	Initial number of discovered degrons: 2
# 		Length of(363, 372): 9
# 		Length of(366, 375): 9
# 	Final number of discovered degrons: 1
# 		[(363, 375)]
# 		Length of (363, 375): 12
#
# 	Degron discovered in protein ENST00000276659
# 	Initial number of discovered degrons: 3
# 		Length of(16, 25): 9
# 		Length of(18, 27): 9
# 		Length of(192, 201): 9
# 	Final number of discovered degrons: 2
# 		[(16, 27), (192, 201)]
# 		Length of (16, 27): 11
# 		Length of (192, 201): 9
#
# 	Degron discovered in protein ENST00000278618
# 	Initial number of discovered degrons: 2
# 		Length of(74, 83): 9
# 		Length of(77, 86): 9
# 	Final number of discovered degrons: 1
# 		[(74, 86)]
# 		Length of (74, 86): 12
#
# 	Degron discovered in protein ENST00000278829
# 	Initial number of discovered degrons: 4
# 		Length of(209, 218): 9
# 		Length of(214, 223): 9
# 		Length of(333, 342): 9
# 		Length of(334, 343): 9
# 	Final number of discovered degrons: 2
# 		[(209, 223), (333, 343)]
# 		Length of (209, 223): 14
# 		Length of (333, 343): 10
#
# 	Degron discovered in protein ENST00000279227
# 	Initial number of discovered degrons: 3
# 		Length of(64, 73): 9
# 		Length of(592, 601): 9
# 		Length of(598, 607): 9
# 	Final number of discovered degrons: 2
# 		[(64, 73), (592, 607)]
# 		Length of (64, 73): 9
# 		Length of (592, 607): 15
#
# 	Degron discovered in protein ENST00000280258
# 	Initial number of discovered degrons: 2
# 		Length of(214, 223): 9
# 		Length of(217, 226): 9
# 	Final number of discovered degrons: 1
# 		[(214, 226)]
# 		Length of (214, 226): 12
#
# 	Degron discovered in protein ENST00000280551
# 	Initial number of discovered degrons: 2
# 		Length of(965, 974): 9
# 		Length of(968, 977): 9
# 	Final number of discovered degrons: 1
# 		[(965, 977)]
# 		Length of (965, 977): 12
#
# 	Degron discovered in protein ENST00000282020
# 	Initial number of discovered degrons: 6
# 		Length of(700, 709): 9
# 		Length of(701, 710): 9
# 		Length of(703, 712): 9
# 		Length of(704, 713): 9
# 		Length of(705, 714): 9
# 		Length of(707, 716): 9
# 	Final number of discovered degrons: 1
# 		[(700, 716)]
# 		Length of (700, 716): 16
#
# 	Degron discovered in protein ENST00000282096
# 	Initial number of discovered degrons: 3
# 		Length of(164, 173): 9
# 		Length of(166, 175): 9
# 		Length of(169, 178): 9
# 	Final number of discovered degrons: 1
# 		[(164, 178)]
# 		Length of (164, 178): 14
#
# 	Degron discovered in protein ENST00000283131
# 	Initial number of discovered degrons: 3
# 		Length of(516, 525): 9
# 		Length of(519, 528): 9
# 		Length of(646, 655): 9
# 	Final number of discovered degrons: 2
# 		[(516, 528), (646, 655)]
# 		Length of (516, 528): 12
# 		Length of (646, 655): 9
#
# 	Degron discovered in protein ENST00000283195
# 	Initial number of discovered degrons: 2
# 		Length of(2961, 2970): 9
# 		Length of(2965, 2974): 9
# 	Final number of discovered degrons: 1
# 		[(2961, 2974)]
# 		Length of (2961, 2974): 13
#
# 	Degron discovered in protein ENST00000283474
# 	Initial number of discovered degrons: 2
# 		Length of(53, 62): 9
# 		Length of(54, 63): 9
# 	Final number of discovered degrons: 1
# 		[(53, 63)]
# 		Length of (53, 63): 10
#
# 	Degron discovered in protein ENST00000284136
# 	Initial number of discovered degrons: 2
# 		Length of(731, 740): 9
# 		Length of(734, 743): 9
# 	Final number of discovered degrons: 1
# 		[(731, 743)]
# 		Length of (731, 743): 12
#
# 	Degron discovered in protein ENST00000285071
# 	Initial number of discovered degrons: 3
# 		Length of(168, 177): 9
# 		Length of(169, 178): 9
# 		Length of(170, 179): 9
# 	Final number of discovered degrons: 1
# 		[(168, 179)]
# 		Length of (168, 179): 11
#
# 	Degron discovered in protein ENST00000285279
# 	Initial number of discovered degrons: 2
# 		Length of(60, 69): 9
# 		Length of(61, 70): 9
# 	Final number of discovered degrons: 1
# 		[(60, 70)]
# 		Length of (60, 70): 10
#
# 	Degron discovered in protein ENST00000285968
# 	Initial number of discovered degrons: 2
# 		Length of(417, 426): 9
# 		Length of(422, 431): 9
# 	Final number of discovered degrons: 1
# 		[(417, 431)]
# 		Length of (417, 431): 14
#
# 	Degron discovered in protein ENST00000286628
# 	Initial number of discovered degrons: 3
# 		Length of(79, 88): 9
# 		Length of(698, 707): 9
# 		Length of(699, 708): 9
# 	Final number of discovered degrons: 2
# 		[(79, 88), (698, 708)]
# 		Length of (79, 88): 9
# 		Length of (698, 708): 10
#
# 	Degron discovered in protein ENST00000286744
# 	Initial number of discovered degrons: 4
# 		Length of(105, 114): 9
# 		Length of(1029, 1038): 9
# 		Length of(1031, 1040): 9
# 		Length of(1133, 1142): 9
# 	Final number of discovered degrons: 3
# 		[(105, 114), (1029, 1040), (1133, 1142)]
# 		Length of (105, 114): 9
# 		Length of (1029, 1040): 11
# 		Length of (1133, 1142): 9
#
# 	Degron discovered in protein ENST00000286808
# 	Initial number of discovered degrons: 2
# 		Length of(47, 56): 9
# 		Length of(50, 59): 9
# 	Final number of discovered degrons: 1
# 		[(47, 59)]
# 		Length of (47, 59): 12
#
# 	Degron discovered in protein ENST00000286835
# 	Initial number of discovered degrons: 2
# 		Length of(879, 888): 9
# 		Length of(882, 891): 9
# 	Final number of discovered degrons: 1
# 		[(879, 891)]
# 		Length of (879, 891): 12
#
# 	Degron discovered in protein ENST00000287239
# 	Initial number of discovered degrons: 4
# 		Length of(857, 866): 9
# 		Length of(2018, 2027): 9
# 		Length of(2019, 2028): 9
# 		Length of(2020, 2029): 9
# 	Final number of discovered degrons: 2
# 		[(857, 866), (2018, 2029)]
# 		Length of (857, 866): 9
# 		Length of (2018, 2029): 11
#
# 	Degron discovered in protein ENST00000287380
# 	Initial number of discovered degrons: 2
# 		Length of(523, 532): 9
# 		Length of(524, 533): 9
# 	Final number of discovered degrons: 1
# 		[(523, 533)]
# 		Length of (523, 533): 10
#
# 	Degron discovered in protein ENST00000287936
# 	Initial number of discovered degrons: 2
# 		Length of(28, 37): 9
# 		Length of(29, 38): 9
# 	Final number of discovered degrons: 1
# 		[(28, 38)]
# 		Length of (28, 38): 10
#
# 	Degron discovered in protein ENST00000288025
# 	Initial number of discovered degrons: 4
# 		Length of(169, 178): 9
# 		Length of(172, 181): 9
# 		Length of(175, 184): 9
# 		Length of(177, 186): 9
# 	Final number of discovered degrons: 1
# 		[(169, 186)]
# 		Length of (169, 186): 17
#
# 	Degron discovered in protein ENST00000288135
# 	Initial number of discovered degrons: 2
# 		Length of(344, 353): 9
# 		Length of(345, 354): 9
# 	Final number of discovered degrons: 1
# 		[(344, 354)]
# 		Length of (344, 354): 10
#
# 	Degron discovered in protein ENST00000288139
# 	Initial number of discovered degrons: 13
# 		Length of(1, 10): 9
# 		Length of(2, 11): 9
# 		Length of(3, 12): 9
# 		Length of(4, 13): 9
# 		Length of(5, 14): 9
# 		Length of(7, 16): 9
# 		Length of(489, 498): 9
# 		Length of(490, 499): 9
# 		Length of(521, 530): 9
# 		Length of(523, 532): 9
# 		Length of(524, 533): 9
# 		Length of(525, 534): 9
# 		Length of(1150, 1159): 9
# 	Final number of discovered degrons: 4
# 		[(1, 16), (489, 499), (521, 534), (1150, 1159)]
# 		Length of (1, 16): 15
# 		Length of (489, 499): 10
# 		Length of (521, 534): 13
# 		Length of (1150, 1159): 9
#
# 	Degron discovered in protein ENST00000288532
# 	Initial number of discovered degrons: 2
# 		Length of(82, 91): 9
# 		Length of(83, 92): 9
# 	Final number of discovered degrons: 1
# 		[(82, 92)]
# 		Length of (82, 92): 10
#
# 	Degron discovered in protein ENST00000289429
# 	Initial number of discovered degrons: 2
# 		Length of(230, 239): 9
# 		Length of(233, 242): 9
# 	Final number of discovered degrons: 1
# 		[(230, 242)]
# 		Length of (230, 242): 12
#
# 	Degron discovered in protein ENST00000290650
# 	Initial number of discovered degrons: 2
# 		Length of(883, 892): 9
# 		Length of(884, 893): 9
# 	Final number of discovered degrons: 1
# 		[(883, 893)]
# 		Length of (883, 893): 10
#
# 	Degron discovered in protein ENST00000290846
# 	Initial number of discovered degrons: 2
# 		Length of(323, 332): 9
# 		Length of(325, 334): 9
# 	Final number of discovered degrons: 1
# 		[(323, 334)]
# 		Length of (323, 334): 11
#
# 	Degron discovered in protein ENST00000291576
# 	Initial number of discovered degrons: 2
# 		Length of(862, 871): 9
# 		Length of(863, 872): 9
# 	Final number of discovered degrons: 1
# 		[(862, 872)]
# 		Length of (862, 872): 10
#
# 	Degron discovered in protein ENST00000292090
# 	Initial number of discovered degrons: 2
# 		Length of(148, 157): 9
# 		Length of(153, 162): 9
# 	Final number of discovered degrons: 1
# 		[(148, 162)]
# 		Length of (148, 162): 14
#
# 	Degron discovered in protein ENST00000294753
# 	Initial number of discovered degrons: 2
# 		Length of(414, 423): 9
# 		Length of(417, 426): 9
# 	Final number of discovered degrons: 1
# 		[(414, 426)]
# 		Length of (414, 426): 12
#
# ...
# 		Length of(2, 12): 10
# 		Length of(38, 48): 10
# 		Length of(40, 50): 10
# 	Final number of discovered degrons: 2
# 		[(2, 12), (38, 50)]
# 		Length of (2, 12): 10
# 		Length of (38, 50): 12
#
# 	Degron discovered in protein ENST00000618040
# 	Initial number of discovered degrons: 3
# 		Length of(38, 48): 10
# 		Length of(39, 49): 10
# 		Length of(42, 52): 10
# 	Final number of discovered degrons: 1
# 		[(38, 52)]
# 		Length of (38, 52): 14
#
# 	Degron discovered in protein ENST00000618101
# 	Initial number of discovered degrons: 5
# 		Length of(124, 134): 10
# 		Length of(203, 213): 10
# 		Length of(207, 217): 10
# 		Length of(396, 406): 10
# 		Length of(397, 407): 10
# 	Final number of discovered degrons: 3
# 		[(124, 134), (203, 217), (396, 407)]
# 		Length of (124, 134): 10
# 		Length of (203, 217): 14
# 		Length of (396, 407): 11
#
# 	Degron discovered in protein ENST00000618196
# 	Initial number of discovered degrons: 4
# 		Length of(33, 43): 10
# 		Length of(214, 224): 10
# 		Length of(215, 225): 10
# 		Length of(216, 226): 10
# 	Final number of discovered degrons: 2
# 		[(33, 43), (214, 226)]
# 		Length of (33, 43): 10
# 		Length of (214, 226): 12
#
# 	Degron discovered in protein ENST00000618550
# 	Initial number of discovered degrons: 53
# 		Length of(22, 32): 10
# 		Length of(28, 38): 10
# 		Length of(302, 312): 10
# 		Length of(326, 336): 10
# 		Length of(330, 340): 10
# 		Length of(334, 344): 10
# 		Length of(368, 378): 10
# 		Length of(384, 394): 10
# 		Length of(388, 398): 10
# 		Length of(451, 461): 10
# 		Length of(494, 504): 10
# 		Length of(496, 506): 10
# 		Length of(645, 655): 10
# 		Length of(792, 802): 10
# 		Length of(796, 806): 10
# 		Length of(807, 817): 10
# 		Length of(826, 836): 10
# 		Length of(830, 840): 10
# 		Length of(834, 844): 10
# 		Length of(849, 859): 10
# 		Length of(850, 860): 10
# 		Length of(853, 863): 10
# 		Length of(857, 867): 10
# 		Length of(861, 871): 10
# 		Length of(865, 875): 10
# 		Length of(884, 894): 10
# 		Length of(888, 898): 10
# 		Length of(896, 906): 10
# 		Length of(900, 910): 10
# 		Length of(904, 914): 10
# 		Length of(923, 933): 10
# 		Length of(924, 934): 10
# 		Length of(927, 937): 10
# 		Length of(931, 941): 10
# 		Length of(935, 945): 10
# 		Length of(939, 949): 10
# 		Length of(954, 964): 10
# 		Length of(955, 965): 10
# 		Length of(958, 968): 10
# 		Length of(962, 972): 10
# 		Length of(966, 976): 10
# 		Length of(985, 995): 10
# 		Length of(986, 996): 10
# 		Length of(989, 999): 10
# 		Length of(997, 1007): 10
# 		Length of(1020, 1030): 10
# 		Length of(1040, 1050): 10
# 		Length of(1044, 1054): 10
# 		Length of(1060, 1070): 10
# 		Length of(1063, 1073): 10
# 		Length of(1099, 1109): 10
# 		Length of(1100, 1110): 10
# 		Length of(1101, 1111): 10
# 	Final number of discovered degrons: 20
# 		[(22, 38), (302, 312), (326, 344), (368, 378), (384, 398), (451, 461), (494, 506), (645, 655), (792, 806), (807, 817), (826, 844), (849, 875), (884, 914), (923, 949), (954, 976), (985, 1007), (1020, 1030), (1040, 1054), (1060, 1073), (1099, 1111)]
# 		Length of (22, 38): 16
# 		Length of (302, 312): 10
# 		Length of (326, 344): 18
# 		Length of (368, 378): 10
# 		Length of (384, 398): 14
# 		Length of (451, 461): 10
# 		Length of (494, 506): 12
# 		Length of (645, 655): 10
# 		Length of (792, 806): 14
# 		Length of (807, 817): 10
# 		Length of (826, 844): 18
# 		Length of (849, 875): 26
# 		Length of (884, 914): 30
# 		Length of (923, 949): 26
# 		Length of (954, 976): 22
# 		Length of (985, 1007): 22
# 		Length of (1020, 1030): 10
# 		Length of (1040, 1054): 14
# 		Length of (1060, 1073): 13
# 		Length of (1099, 1111): 12
#
# 	Degron discovered in protein ENST00000618554
# 	Initial number of discovered degrons: 3
# 		Length of(154, 164): 10
# 		Length of(155, 165): 10
# 		Length of(158, 168): 10
# 	Final number of discovered degrons: 1
# 		[(154, 168)]
# 		Length of (154, 168): 14
#
# 	Degron discovered in protein ENST00000618634
# 	Initial number of discovered degrons: 2
# 		Length of(216, 226): 10
# 		Length of(220, 230): 10
# 	Final number of discovered degrons: 1
# 		[(216, 230)]
# 		Length of (216, 230): 14
#
# 	Degron discovered in protein ENST00000618852
# 	Initial number of discovered degrons: 33
# 		Length of(300, 310): 10
# 		Length of(314, 324): 10
# 		Length of(317, 327): 10
# 		Length of(318, 328): 10
# 		Length of(319, 329): 10
# 		Length of(320, 330): 10
# 		Length of(321, 331): 10
# 		Length of(328, 338): 10
# 		Length of(329, 339): 10
# 		Length of(330, 340): 10
# 		Length of(331, 341): 10
# 		Length of(342, 352): 10
# 		Length of(343, 353): 10
# 		Length of(344, 354): 10
# 		Length of(346, 356): 10
# 		Length of(347, 357): 10
# 		Length of(359, 369): 10
# 		Length of(362, 372): 10
# 		Length of(364, 374): 10
# 		Length of(365, 375): 10
# 		Length of(376, 386): 10
# 		Length of(387, 397): 10
# 		Length of(388, 398): 10
# 		Length of(389, 399): 10
# 		Length of(390, 400): 10
# 		Length of(391, 401): 10
# 		Length of(392, 402): 10
# 		Length of(393, 403): 10
# 		Length of(394, 404): 10
# 		Length of(395, 405): 10
# 		Length of(396, 406): 10
# 		Length of(397, 407): 10
# 		Length of(398, 408): 10
# 	Final number of discovered degrons: 6
# 		[(300, 310), (314, 341), (342, 357), (359, 375), (376, 386), (387, 408)]
# 		Length of (300, 310): 10
# 		Length of (314, 341): 27
# 		Length of (342, 357): 15
# 		Length of (359, 375): 16
# 		Length of (376, 386): 10
# 		Length of (387, 408): 21
#
# 	Degron discovered in protein ENST00000619208
# 	Initial number of discovered degrons: 6
# 		Length of(734, 744): 10
# 		Length of(792, 802): 10
# 		Length of(949, 959): 10
# 		Length of(991, 1001): 10
# 		Length of(1006, 1016): 10
# 		Length of(1008, 1018): 10
# 	Final number of discovered degrons: 5
# 		[(734, 744), (792, 802), (949, 959), (991, 1001), (1006, 1018)]
# 		Length of (734, 744): 10
# 		Length of (792, 802): 10
# 		Length of (949, 959): 10
# 		Length of (991, 1001): 10
# 		Length of (1006, 1018): 12
#
# 	Degron discovered in protein ENST00000619243
# 	Initial number of discovered degrons: 2
# 		Length of(21, 31): 10
# 		Length of(24, 34): 10
# 	Final number of discovered degrons: 1
# 		[(21, 34)]
# 		Length of (21, 34): 13
#
# 	Degron discovered in protein ENST00000619644
# 	Initial number of discovered degrons: 2
# 		Length of(285, 295): 10
# 		Length of(289, 299): 10
# 	Final number of discovered degrons: 1
# 		[(285, 299)]
# 		Length of (285, 299): 14
#
# 	Degron discovered in protein ENST00000619918
# 	Initial number of discovered degrons: 9
# 		Length of(322, 332): 10
# 		Length of(324, 334): 10
# 		Length of(326, 336): 10
# 		Length of(328, 338): 10
# 		Length of(329, 339): 10
# 		Length of(330, 340): 10
# 		Length of(331, 341): 10
# 		Length of(790, 800): 10
# 		Length of(1190, 1200): 10
# 	Final number of discovered degrons: 3
# 		[(322, 341), (790, 800), (1190, 1200)]
# 		Length of (322, 341): 19
# 		Length of (790, 800): 10
# 		Length of (1190, 1200): 10
#
# 	Degron discovered in protein ENST00000620264
# 	Initial number of discovered degrons: 16
# 		Length of(396, 406): 10
# 		Length of(397, 407): 10
# 		Length of(398, 408): 10
# 		Length of(399, 409): 10
# 		Length of(400, 410): 10
# 		Length of(401, 411): 10
# 		Length of(402, 412): 10
# 		Length of(403, 413): 10
# 		Length of(404, 414): 10
# 		Length of(405, 415): 10
# 		Length of(406, 416): 10
# 		Length of(407, 417): 10
# 		Length of(408, 418): 10
# 		Length of(409, 419): 10
# 		Length of(410, 420): 10
# 		Length of(619, 629): 10
# 	Final number of discovered degrons: 2
# 		[(396, 420), (619, 629)]
# 		Length of (396, 420): 24
# 		Length of (619, 629): 10
#
# 	Degron discovered in protein ENST00000620676
# 	Initial number of discovered degrons: 3
# 		Length of(770, 780): 10
# 		Length of(774, 784): 10
# 		Length of(1757, 1767): 10
# 	Final number of discovered degrons: 2
# 		[(770, 784), (1757, 1767)]
# 		Length of (770, 784): 14
# 		Length of (1757, 1767): 10
#
# 	Degron discovered in protein ENST00000620804
# 	Initial number of discovered degrons: 9
# 		Length of(322, 332): 10
# 		Length of(324, 334): 10
# 		Length of(326, 336): 10
# 		Length of(328, 338): 10
# 		Length of(329, 339): 10
# 		Length of(330, 340): 10
# 		Length of(331, 341): 10
# 		Length of(790, 800): 10
# 		Length of(1190, 1200): 10
# 	Final number of discovered degrons: 3
# 		[(322, 341), (790, 800), (1190, 1200)]
# 		Length of (322, 341): 19
# 		Length of (790, 800): 10
# 		Length of (1190, 1200): 10
#
# 	Degron discovered in protein ENST00000621198
# 	Initial number of discovered degrons: 6
# 		Length of(29, 39): 10
# 		Length of(30, 40): 10
# 		Length of(31, 41): 10
# 		Length of(32, 42): 10
# 		Length of(33, 43): 10
# 		Length of(479, 489): 10
# 	Final number of discovered degrons: 2
# 		[(29, 43), (479, 489)]
# 		Length of (29, 43): 14
# 		Length of (479, 489): 10
#
# 	Degron discovered in protein ENST00000622611
# 	Initial number of discovered degrons: 8
# 		Length of(339, 349): 10
# 		Length of(341, 351): 10
# 		Length of(342, 352): 10
# 		Length of(350, 360): 10
# 		Length of(366, 376): 10
# 		Length of(380, 390): 10
# 		Length of(410, 420): 10
# 		Length of(411, 421): 10
# 	Final number of discovered degrons: 4
# 		[(339, 360), (366, 376), (380, 390), (410, 421)]
# 		Length of (339, 360): 21
# 		Length of (366, 376): 10
# 		Length of (380, 390): 10
# 		Length of (410, 421): 11
#
# 	Degron discovered in protein ENST00000622749
# 	Initial number of discovered degrons: 3
# 		Length of(220, 230): 10
# 		Length of(221, 231): 10
# 		Length of(223, 233): 10
# 	Final number of discovered degrons: 1
# 		[(220, 233)]
# 		Length of (220, 233): 13
#
# 	Degron discovered in protein ENST00000623213
# 	Initial number of discovered degrons: 3
# 		Length of(1784, 1794): 10
# 		Length of(1842, 1852): 10
# 		Length of(1844, 1854): 10
# 	Final number of discovered degrons: 2
# 		[(1784, 1794), (1842, 1854)]
# 		Length of (1784, 1794): 10
# 		Length of (1842, 1854): 12
#
# 	Degron discovered in protein ENST00000627582
# 	Initial number of discovered degrons: 3
# 		Length of(759, 769): 10
# 		Length of(809, 819): 10
# 		Length of(811, 821): 10
# 	Final number of discovered degrons: 2
# 		[(759, 769), (809, 821)]
# 		Length of (759, 769): 10
# 		Length of (809, 821): 12
#
# 	Degron discovered in protein ENST00000632009
# 	Initial number of discovered degrons: 2
# 		Length of(576, 586): 10
# 		Length of(579, 589): 10
# 	Final number of discovered degrons: 1
# 		[(576, 589)]
# 		Length of (576, 589): 13
#
# 	Degron discovered in protein ENST00000635964
# 	Initial number of discovered degrons: 3
# 		Length of(84, 94): 10
# 		Length of(85, 95): 10
# 		Length of(87, 97): 10
# 	Final number of discovered degrons: 1
# 		[(84, 97)]
# 		Length of (84, 97): 13
#
# 	Degron discovered in protein ENST00000636331
# 	Initial number of discovered degrons: 5
# 		Length of(84, 94): 10
# 		Length of(103, 113): 10
# 		Length of(106, 116): 10
# 		Length of(107, 117): 10
# 		Length of(110, 120): 10
# 	Final number of discovered degrons: 2
# 		[(84, 94), (103, 120)]
# 		Length of (84, 94): 10
# 		Length of (103, 120): 17
#
# 	Degron discovered in protein ENST00000638972
# 	Initial number of discovered degrons: 9
# 		Length of(101, 111): 10
# 		Length of(139, 149): 10
# 		Length of(140, 150): 10
# 		Length of(141, 151): 10
# 		Length of(142, 152): 10
# 		Length of(143, 153): 10
# 		Length of(144, 154): 10
# 		Length of(145, 155): 10
# 		Length of(147, 157): 10
# 	Final number of discovered degrons: 2
# 		[(101, 111), (139, 157)]
# 		Length of (101, 111): 10
# 		Length of (139, 157): 18
#
# 	Degron discovered in protein ENST00000639579
# 	Initial number of discovered degrons: 6
# 		Length of(26, 36): 10
# 		Length of(28, 38): 10
# 		Length of(29, 39): 10
# 		Length of(30, 40): 10
# 		Length of(31, 41): 10
# 		Length of(92, 102): 10
# 	Final number of discovered degrons: 2
# 		[(26, 41), (92, 102)]
# 		Length of (26, 41): 15
# 		Length of (92, 102): 10
#
# 	Degron discovered in protein ENST00000640853
# 	Initial number of discovered degrons: 3
# 		Length of(64, 74): 10
# 		Length of(65, 75): 10
# 		Length of(67, 77): 10
# 	Final number of discovered degrons: 1
# 		[(64, 77)]
# 		Length of (64, 77): 13
#
# 	Degron discovered in protein ENST00000641206
# 	Initial number of discovered degrons: 15
# 		Length of(2032, 2042): 10
# 		Length of(2034, 2044): 10
# 		Length of(2035, 2045): 10
# 		Length of(2036, 2046): 10
# 		Length of(2037, 2047): 10
# 		Length of(2038, 2048): 10
# 		Length of(2039, 2049): 10
# 		Length of(2040, 2050): 10
# 		Length of(2041, 2051): 10
# 		Length of(2042, 2052): 10
# 		Length of(2043, 2053): 10
# 		Length of(2479, 2489): 10
# 		Length of(2483, 2493): 10
# 		Length of(3208, 3218): 10
# 		Length of(3209, 3219): 10
# 	Final number of discovered degrons: 3
# 		[(2032, 2053), (2479, 2493), (3208, 3219)]
# 		Length of (2032, 2053): 21
# 		Length of (2479, 2493): 14
# 		Length of (3208, 3219): 11
#
# 	Degron discovered in protein ENST00000642278
# 	Initial number of discovered degrons: 2
# 		Length of(621, 631): 10
# 		Length of(625, 635): 10
# 	Final number of discovered degrons: 1
# 		[(621, 635)]
# 		Length of (621, 635): 14
#
# 	Degron discovered in protein ENST00000642316
# 	Initial number of discovered degrons: 2
# 		Length of(657, 667): 10
# 		Length of(661, 671): 10
# 	Final number of discovered degrons: 1
# 		[(657, 671)]
# 		Length of (657, 671): 14
#
# 	Degron discovered in protein ENST00000642384
# 	Initial number of discovered degrons: 3
# 		Length of(258, 268): 10
# 		Length of(353, 363): 10
# 		Length of(359, 369): 10
# 	Final number of discovered degrons: 2
# 		[(258, 268), (353, 369)]
# 		Length of (258, 268): 10
# 		Length of (353, 369): 16
#
# 	Degron discovered in protein ENST00000642864
# 	Initial number of discovered degrons: 23
# 		Length of(550, 560): 10
# 		Length of(1175, 1185): 10
# 		Length of(1176, 1186): 10
# 		Length of(1177, 1187): 10
# 		Length of(1178, 1188): 10
# 		Length of(1179, 1189): 10
# 		Length of(1180, 1190): 10
# 		Length of(1181, 1191): 10
# 		Length of(1182, 1192): 10
# 		Length of(1183, 1193): 10
# 		Length of(1275, 1285): 10
# 		Length of(1279, 1289): 10
# 		Length of(1288, 1298): 10
# 		Length of(1289, 1299): 10
# 		Length of(1292, 1302): 10
# 		Length of(1305, 1315): 10
# 		Length of(1428, 1438): 10
# 		Length of(1432, 1442): 10
# 		Length of(1433, 1443): 10
# 		Length of(1436, 1446): 10
# 		Length of(1438, 1448): 10
# 		Length of(1448, 1458): 10
# 		Length of(1451, 1461): 10
# 	Final number of discovered degrons: 6
# 		[(550, 560), (1175, 1193), (1275, 1302), (1305, 1315), (1428, 1448), (1448, 1461)]
# 		Length of (550, 560): 10
# 		Length of (1175, 1193): 18
# 		Length of (1275, 1302): 27
# 		Length of (1305, 1315): 10
# 		Length of (1428, 1448): 20
# 		Length of (1448, 1461): 13
#
# 	Degron discovered in protein ENST00000643483
# 	Initial number of discovered degrons: 5
# 		Length of(165, 175): 10
# 		Length of(169, 179): 10
# 		Length of(276, 286): 10
# 		Length of(278, 288): 10
# 		Length of(378, 388): 10
# 	Final number of discovered degrons: 3
# 		[(165, 179), (276, 288), (378, 388)]
# 		Length of (165, 179): 14
# 		Length of (276, 288): 12
# 		Length of (378, 388): 10
#
# 	Degron discovered in protein ENST00000644072
# 	Initial number of discovered degrons: 2
# 		Length of(4, 14): 10
# 		Length of(7, 17): 10
# 	Final number of discovered degrons: 1
# 		[(4, 17)]
# 		Length of (4, 17): 13
#
# 	Degron discovered in protein ENST00000645284
# 	Initial number of discovered degrons: 22
# 		Length of(425, 435): 10
# 		Length of(426, 436): 10
# 		Length of(428, 438): 10
# 		Length of(429, 439): 10
# 		Length of(430, 440): 10
# 		Length of(432, 442): 10
# 		Length of(433, 443): 10
# 		Length of(434, 444): 10
# 		Length of(435, 445): 10
# 		Length of(436, 446): 10
# 		Length of(442, 452): 10
# 		Length of(444, 454): 10
# 		Length of(446, 456): 10
# 		Length of(447, 457): 10
# 		Length of(592, 602): 10
# 		Length of(593, 603): 10
# 		Length of(594, 604): 10
# 		Length of(595, 605): 10
# 		Length of(596, 606): 10
# 		Length of(597, 607): 10
# 		Length of(598, 608): 10
# 		Length of(599, 609): 10
# 	Final number of discovered degrons: 2
# 		[(425, 457), (592, 609)]
# 		Length of (425, 457): 32
# 		Length of (592, 609): 17
#
# 	Degron discovered in protein ENST00000646038
# 	Initial number of discovered degrons: 18
# 		Length of(598, 608): 10
# 		Length of(599, 609): 10
# 		Length of(600, 610): 10
# 		Length of(601, 611): 10
# 		Length of(602, 612): 10
# 		Length of(603, 613): 10
# 		Length of(604, 614): 10
# 		Length of(605, 615): 10
# 		Length of(607, 617): 10
# 		Length of(608, 618): 10
# 		Length of(609, 619): 10
# 		Length of(610, 620): 10
# 		Length of(611, 621): 10
# 		Length of(612, 622): 10
# 		Length of(613, 623): 10
# 		Length of(614, 624): 10
# 		Length of(620, 630): 10
# 		Length of(1352, 1362): 10
# 	Final number of discovered degrons: 2
# 		[(598, 630), (1352, 1362)]
# 		Length of (598, 630): 32
# 		Length of (1352, 1362): 10
#
#
# Motif: MDM2.tsv.gz
#
# Maximum degron length obtained after pooling all overlapping degrons: 50

# %% [markdown]
# ## 2. Pool those degrons overlapping

# %%
def pool_seqs(idx, start_coords, end_coords, entire_protein):
    
    first = True   # Flag

    new_start_coords = []
    new_end_coords = []
    new_seqs = []
    idxs = []
    
    for s, e in zip(start_coords, end_coords):
        if first:
            new_s = s
            new_e = e
            first = False
        
        elif (new_s < s and new_e > s) or \
        (new_s < e and new_e > e):   # the 2nd option should not happen as the scan moves forward, but just in case
            new_s = min(new_s, s)
            new_e = max(new_e, e)
        
        else:
            new_seqs.append(entire_protein[new_s-1: new_e])
            new_start_coords.append(new_s)
            new_end_coords.append(new_e)
            idxs.append(idx)
            
            new_s = s
            new_e = e
    
    new_seqs.append(entire_protein[new_s-1: new_e])
    new_start_coords.append(new_s)
    new_end_coords.append(new_e)
    idxs.append(idx)
    
    return idxs, new_seqs, new_start_coords, new_end_coords

# %%
motifs = os.listdir(all_discov_degrons_path)

# One by one motif analysis
for motif in motifs:
    
    print(f'Motif: {motif}')    
    discov_degrons = pd.read_csv(all_discov_degrons_path+motif, sep = "\t", compression = "gzip")
    print(f'\tInitial number of degrons: {len(discov_degrons)}')
    
    all_idxs = []
    all_new_seqs = []
    all_new_start_coords = []
    all_new_end_coords = []
    
    # Obtain proteins having the same degron discovered more than once
    discov_degrons_c = discov_degrons.groupby(["protein_id"]).size(
    ).reset_index().rename(columns = {0:'count'})
    discov_degrons_c_more1_id = discov_degrons_c.loc[discov_degrons_c["count"] > 1, "protein_id"].values
    
    # For each protein, obtain all the coordinates of the found degrons
    for idx in discov_degrons_c_more1_id:
        degron_starts = discov_degrons.loc[discov_degrons.protein_id == idx, "start"].values
        degron_ends = discov_degrons.loc[discov_degrons.protein_id == idx, "end"].values
        entire_protein = proteome[idx]    # to retrieve new pooled degron sequence
        
        # Remove old degrons found in a certain protein
        discov_degrons.drop(discov_degrons[discov_degrons.protein_id == idx].index, inplace = True)
        
        # Generate and add new degrons found in a certain protein (some could be the same if not pooled)
        idxs, new_seqs, new_start_coords, new_end_coords = pool_seqs(idx, degron_starts, degron_ends, entire_protein)
        all_idxs = all_idxs + idxs
        all_new_seqs = all_new_seqs + new_seqs
        all_new_start_coords = all_new_start_coords + new_start_coords
        all_new_end_coords = all_new_end_coords + new_end_coords
    
    new_degrons = pd.DataFrame(list(zip(all_idxs, all_new_seqs, 
                                     all_new_start_coords, 
                                     all_new_end_coords)),
                             columns = ["protein_id", "sequence",
                                        "start", "end"])
    
    discov_degrons = pd.concat([discov_degrons, new_degrons], ignore_index = True)
    print(f'\tFinal number of degrons: {len(discov_degrons)}') 
    
    discov_degrons.to_csv(all_discov_degrons_overlapool_path+motif, sep = "\t", index = False)
# Out:
# Motif: APC_ABBA.tsv.gz
# 	Initial number of degrons: 44
# 	Final number of degrons: 44
# Motif: APC_KENBOX.tsv.gz
# 	Initial number of degrons: 978
# 	Final number of degrons: 975
# Motif: BTRC.tsv.gz
# 	Initial number of degrons: 152
# 	Final number of degrons: 152
# Motif: CBLL1.tsv.gz
# 	Initial number of degrons: 4
# 	Final number of degrons: 4
# Motif: CBL_MET.tsv.gz
# 	Initial number of degrons: 777
# 	Final number of degrons: 755
# Motif: CBL_PTK.tsv.gz
# 	Initial number of degrons: 1849
# 	Final number of degrons: 1847
# Motif: DEG_APCC_TPR_1.tsv.gz
# 	Initial number of degrons: 7330
# 	Final number of degrons: 6315
# Motif: DEG_Kelch_KLHL3_1.tsv.gz
# 	Initial number of degrons: 4
# 	Final number of degrons: 4
# Motif: DEG_Nend_UBRbox_4.tsv.gz
# 	Initial number of degrons: 3
# 	Final number of degrons: 3
# Motif: VHL.tsv.gz
# 	Initial number of degrons: 9
# 	Final number of degrons: 9
# Motif: KEAP1.tsv.gz
# 	Initial number of degrons: 611
# 	Final number of degrons: 610
# Motif: SPOP.tsv.gz
# 	Initial number of degrons: 13446
# 	Final number of degrons: 12719
# Motif: FBXO31.tsv.gz
# 	Initial number of degrons: 3
# 	Final number of degrons: 3
# Motif: SIAH1.tsv.gz
# 	Initial number of degrons: 21
# 	Final number of degrons: 21
# Motif: COP1.tsv.gz
# 	Initial number of degrons: 8
# 	Final number of degrons: 8
# Motif: DTL.tsv.gz
# 	Initial number of degrons: 65
# 	Final number of degrons: 61
# Motif: FBXW7.tsv.gz
# 	Initial number of degrons: 9935
# 	Final number of degrons: 5280
# Motif: MDM2.tsv.gz
# 	Initial number of degrons: 57
# 	Final number of degrons: 57
