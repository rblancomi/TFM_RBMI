# %% [markdown]
# # TFM Figures

# %% [markdown]
# This notebook contains all the code to reproduce the plots in the figures of the final manuscripts where the data analysis is performed.

# %%
# %load_ext jupyternotify
# Out:
# The jupyternotify extension is already loaded. To reload it, use:
#   %reload_ext jupyternotify

# %% [markdown]
# ## Import libraries

# %%
# to reload automatically the changes in the scripts.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
tqdm.pandas()
# %matplotlib inline

## my modules ##
sys.path.append("../scripts/Utils/")    # modules folder
from motif_utils import motif_scan_flex, motif_logo
from fasta_utils import readFasta_gzip
from stabch_utils import *
from plots_utils import *
from loads_utils import load_bg_aa

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Define paths

# %%
base = "../"

data = "data/"
results = "results/"

ubinet_validation_path = os.path.join(base, data, "ubinet/ubinet_elm_manual_validation.tsv")

n_hits_per_protein_elm_manual_path = os.path.join(base, results, 
"quality_analysis/hits_per_protein_elm_manual.tsv.gz")
qa_elm_manual_path = os.path.join(base, results, "quality_analysis/motifs_quality_analysis_elm_manual.tsv.gz")

elm_manual_pos_scan_path = os.path.join(base, data, "elm_manual/scan_70k/positive_set_scan/")
elm_manual_nopos_scan_path = os.path.join(base, data, "elm_manual/scan_70k/no_positive_set_scan/")

elm_manual_pos_set_path = os.path.join(base, data "elm_manual/positive_set_fasta/")
elm_manual_enrich_pos_set_path = os.path.join(base, data, "elm_manual/positive_set_enrich_fasta/")

elm_manual_pwms_path = os.path.join(base, data, "elm_manual/motif_matrices/PWM/")

proteome_path = os.path.join(base, data, "external/uniprot/uniprot_proteome_UP000005640.fasta.gz")
small_proteome_path = os.path.join(base, data, "external/biomart/biomart92_proteome_cantranscripts_uniq_prepro.fasta.gz")

stabch_panc_cptac_path = os.path.join(base, results, 
"stability_change_annot_degrons/stability_change_cptacms.tsv.gz")
stabch_panc_ccle_path = os.path.join(base, results, 
"stability_change_annot_degrons/stability_change_cclems_wth_ctype.tsv.gz")

aa_bg_path = os.path.join(base, data, "external/aminoacid_frequency.txt")

plots_path = os.path.join(base, results, "figures/")

# %% [markdown]
# ## Load data

# %% [markdown]
# ### UbiNet PWMs validation with ELM degron instances

# %%
ubinet_validation = pd.read_csv(ubinet_validation_path, sep = "\t")

# %% [markdown]
# ### ELM-Manual PWMs quality analysis

# %%
qa_elm_manual = pd.read_csv(qa_elm_manual_path, sep = "\t", compression = 'gzip')

# %%
n_hits_per_protein_elm_manual = pd.read_csv(n_hits_per_protein_elm_manual_path, 
                                            sep = "\t", index_col = 0, compression = 'gzip')

# %% [markdown]
# ### ELM-Manual PWMs scans (true degrons and rest of protein sequences)

# %%
e3_scans_pos_dict = {}
e3_scans = os.listdir(elm_manual_pos_scan_path)
for e3 in e3_scans:
    with open(elm_manual_pos_scan_path+e3) as fp:
        e3_scans_pos_dict[e3.split(".")[0]] = json.load(fp)

# %%
e3_scans_nopos_dict = {}
e3_scans = os.listdir(elm_manual_nopos_scan_path)
for e3 in e3_scans:
    with open(elm_manual_nopos_scan_path+e3) as fp:
        e3_scans_nopos_dict[e3.split(".")[0]] = json.load(fp)

# %% [markdown]
# ### ELM-Manual PWMs

# %%
e3_pwms_dict = {}
e3_pwms = os.listdir(elm_manual_pwms_path)
for e3 in e3_pwms:
    e3_pwms_dict[e3.split(".")[0]] = pd.read_csv(elm_manual_pwms_path+e3, sep = "\t")

# %% [markdown]
# ### ELM-Manual true degrons (positive set dataframes)

# %%
# elm-manual positive set
e3_pos_set_dict = {}
e3_pos_set = os.listdir(elm_manual_pos_set_path)
for e3 in e3_pos_set:
    e3_pos_set_dict[e3.split(".")[0]] = pd.read_csv(elm_manual_pos_set_path+e3, sep = "\t")

# %%
# elm-manual + enriched positive set
e3_enrich_pos_set_dict = {}
e3_enrich_pos_set = os.listdir(elm_manual_enrich_pos_set_path)
for e3 in e3_enrich_pos_set:
    e3_enrich_pos_set_dict[e3.split(".")[0]] = pd.read_csv(elm_manual_enrich_pos_set_path+e3, sep = "\t")

# %% [markdown]
# ### UniProtKB proteome

# %%
proteome = readFasta_gzip(proteome_path)
# Out:
# Number of retrieved sequences: 78120

# %% [markdown]
# ### Ensembl 92 proteome

# %%
small_proteome = readFasta_gzip(small_proteome_path)
# Out:
# Number of retrieved sequences: 19302

# %% [markdown]
# ### CPTAC and CCLE mutations and stability change tables with degrons annotated

# %%
# CCLE MS
ccle_stabch = pd.read_csv(stabch_panc_ccle_path, sep = "\t", compression = "gzip")

# %%
# CPTAC MS
cptac_stabch = pd.read_csv(stabch_panc_cptac_path, sep = "\t", compression = "gzip")

# %% [markdown]
# ## Figure 1. Generation of PWMs. Supplementary S2, S3.

# %% [markdown]
# ### S2. UbiNet validation with ELM-Manual degron instances

# %%
def add_validated_e3(row):
    """
    Annotate as extra column the motif symbol to use it
    as hue in the plot
    """
    
    score = row.Score
    e3_ligase = row.E3_ligase
    
    # annotate motif symbol only if the score is positive
    ## we already know which motifs have a positive score
    if row.Score != 0:
        if row.E3_ligase == "Q969H0":
            row["E3_ligase_symb"] = "FBXW7"
        elif row.E3_ligase == "Q96J02":
            row["E3_ligase_symb"] = "ITCH"
    
    # annotate the rest of motifs with the same label
    else:
        row["E3_ligase_symb"] = "others"
    
    return row

# %%
ubinet_validation = ubinet_validation.apply(lambda row: add_validated_e3(row), axis = 1)

# %%
def one_stripplot(df, plot_file, fig_width = 6, fig_height = 10):
    """
    Stripplot for UbiNet PWMs validation. 
    """
    
    # plot settings
    palette = {"others": "grey", "FBXW7": "#fb9a99", "ITCH": "#1f78b4"}
    sns.set_style(style = 'whitegrid')
    plt.figure(figsize = (fig_width, fig_height))
    
    # stripplot
    ax = sns.stripplot(x = "Dataset", y = "Score", data = df,
                alpha = 0.7, size = 5, color = "#31a354",
                jitter = True, dodge = False, hue = "E3_ligase_symb",
                 palette = palette)

    plt.xticks(np.arange(1), [""], fontsize = 18)
    plt.yticks(fontsize = 15)
    plt.ylabel("PWM Score", fontsize = 15)
    plt.xlabel("", fontsize = 15)
    plt.title("ELM-Manual degrons", fontsize = 18)
    
    # set legend
    legend_cols_dict = [Line2D([0],[0], color ='w', markerfacecolor = "#fb9a99", marker = 'o', 
                               markersize = 8, label = 'FBXW7'),
                       Line2D([0],[0], color ='w', markerfacecolor = "#1f78b4", marker = 'o', 
                               markersize = 8, label = "ITCH")]
                        
    legend = ax.legend(handles = legend_cols_dict, bbox_to_anchor = (1.55, .9),
                         fontsize = 12, framealpha = 0.3)
    ax.add_artist(legend)
    
    # save
    plt.savefig(plot_file, dpi = 800, transparent = True, bbox_inches = "tight")
    
    return ax

# %%
file = os.path.join(plots_path, "ubinet_elm_validation_violinplot.png")
one_stripplot(ubinet_validation, file, fig_width = 3, fig_height = 6)
# Out:
# <AxesSubplot:title={'center':'ELM-Manual degrons'}, ylabel='PWM Score'>

# %% [markdown]
# ### 1B, S3. Degron motifs logos

# %%
# load aa bg probabilities and names separately

aa_probs, aa_names = load_bg_aa(aa_bg_path)

# %%
for E3 in os.listdir(elm_manual_enrich_pos_set_path):
    
    # only take fasta files from the folder
    if E3.split(".")[-1] == "fasta":
        file = os.path.join(plots_path, "logos/", E3.split(".")[0]+".png")

        motif_logo(elm_manual_enrich_pos_set_path+E3, aa_names, file, format = "fasta")
        print(E3)
# Out:
# KEAP1.fasta
# SPOP.fasta
# SIAH1.fasta
# VHL.fasta
# FBXO31.fasta
# FBXW7.fasta
# COP1.fasta
# DTL.fasta
# BTRC.fasta
# MDM2.fasta
# CBL_PTK.fasta
# CBL_MET.fasta
# APC_ABBA.fasta
# DEG_APCC_TPR_1.fasta
# APC_DBOX.fasta
# APC_KENBOX.fasta
# DEG_Kelch_KLHL3_1.fasta
# DEG_Nend_UBRbox_4.fasta
# CBLL1.fasta

# %% [markdown]
# ### 1C. Information content per E3 ligase

# %%
file = os.path.join(plots_path, "info_content_barplot.png")
barplot_qa_property(qa_elm_manual, "motif_info_content", 
                    "Informational content\n per position",
                    file, fig_width = 10, fig_height = 3)
# Out:
# <AxesSubplot:xlabel='Degron motif', ylabel='Informational content\n per position'>

# %% [markdown]
# ## Figure 2. Degron annotation in the human proteome. Supplementary S4, S5

# %% [markdown]
# ### 2B, S4. Different distribution between random sequences and true degrons: positivity threshold

# %%
for E3 in e3_pwms_dict:
    
    file = os.path.join(plots_path, "pos_vs_random_violinplots/"+E3+".png")
    
    pwm = e3_pwms_dict[E3]
    pos_set = e3_pos_set_dict[E3]
    nopos_scan = e3_scans_nopos_dict[E3]
    
    violinplot_pos_threshold(pwm, pos_set, nopos_scan, qa_elm_manual, E3, proteome, file, n_samples = 100,
                             negatives_to_zero = False, fig_width = 2.5, fig_height = 5)

# %% [markdown]
# ### 2C. Degron specificity: correlation index (number of hits vs protein's length)

# %%
file = os.path.join(plots_path, "specificity_corr_barplot.png")
barplot_qa_property(qa_elm_manual, "correlation_hits_vs_length_sequence", 
                    "Correlation index",
                   file, fig_width = 12, fig_height = 3)
# Out:
# <AxesSubplot:xlabel='Degron motif', ylabel='Correlation index'>

# %% [markdown]
# ### 2D. Examples of specificity: number of hits per protein vs length

# %%
E3s = ["APC_DBOX", "MDM2"]

for E3 in E3s:
    print(E3)
    file = os.path.join(plots_path, "specificity_scatterplots/"+E3+".png")
    hits_length_scatterplot(qa_elm_manual, n_hits_per_protein_elm_manual, E3, file, font_y = 16, font_x = 16,
                           fig_width = 5, fig_height = 3.5)
# Out:
# APC_DBOX
# MDM2

# %% [markdown]
# ### 2E. Degron discovery activity: per protein

# %%
# per protein
file = os.path.join(plots_path, "discov_activity_protein_barplot.png")
barplot_broken_axis_qa_property(qa_elm_manual, "number_positive_hits",
                                "Proteins with a discovered degron\n", plot_file = file,
                                y_lim_high = (1000, 80000), y_lim_low = (0, 1000),
                                low_pad_x = 0, high_pad_x = 0, low_pad_y = 10, high_pad_y = 1500,
                                font_y = 16, property_percentage = "percent_positive_hits",
                                n_remove_outliers = 1, fig_width = 12, fig_height = 3)
# Out:
# (<AxesSubplot:>, <AxesSubplot:xlabel='Degron motif'>)

# %% [markdown]
# ### S5A. Degron discovery activity: per protein subsequence

# %%
# per protein subsequence
file = os.path.join(plots_path, "discov_activity_subseq_barplot.png")
barplot_broken_axis_qa_property(qa_elm_manual, "number_positive_hits_subseq",
                                "Discovered degrons\n", plot_file = file,
                                y_lim_high = (3000, 3000000), y_lim_low = (0, 1000),
                                low_pad_x = .22, high_pad_x = .05, low_pad_y = 10, high_pad_y = 150000,
                                font_y = 16, n_remove_outliers = 1,  fig_width = 14, fig_height = 3)
# Out:
# (<AxesSubplot:>, <AxesSubplot:xlabel='Degron motif'>)

# %% [markdown]
# ### S5B. True degrons discovery

# %%
file = os.path.join(plots_path, "discov_activity_true_degrons_barplot.png")
barplot_qa_property(qa_elm_manual, "percent_discovery_msa_seqs", 
                    "% of true degrons discovered", file, fig_width = 12, fig_height = 3)
# Out:
# <AxesSubplot:xlabel='Degron motif', ylabel='% of true degrons discovered'>

# %% [markdown]
# ## Figure 3. Degron validation through non-truncating (missense and inframe) mutations. Supplementary S6

# %% [markdown]
# ### 3A. Overview of the datasets

# %%
file = os.path.join(plots_path, "ccle_piechart.png")
dataset = "CCLE"
palette = ["#a6cee3", "#1f78b4", "#b2df8a", "#33a02c", "#fb9a99", "#e31a1c", "#fdbf6f", "#ff7f00", "#cab2d6",
           "#6a3d9a", "#ffff99"]

dataset_piechart(ccle_stabch, "sample", "cancer_type", dataset, palette, file,
                fig_width = 5, fig_height = 3.5)

# %%
file = os.path.join(plots_path, "cptac_piechart.png")
dataset = "CPTAC"
palette = ["#a6cee3", "#1f78b4", "#b2df8a", "#33a02c", "#fb9a99", "#e31a1c", "#fdbf6f", "#ff7f00", "#cab2d6",
           "#6a3d9a", "#ffff99"]

dataset_piechart(cptac_stabch, "sample", "Cancer_type", dataset, palette, file,
                fig_width = 5, fig_height = 3.5)

# %% [markdown]
# ### 3C. TP53 in LUAD (CPTAC): Stability change calculation

# %%
# Not filter with degrons info
ctype_stabch = pd.read_csv("/workspace/projects/degrons/data/stability_change/CPTAC/LUAD.gz", sep = "\t")

# %%
# To reproduce Martinez-Jimenez et al.: TP53 in COAD 
dataset = "CPTAC"
gene = "TP53"
ctype = "LUAD"

file = os.path.join(plots_path, "TP53_RNAvsProtein_scatterplot.png")
rna_vs_protein_scatterplot(ctype_stabch, gene, ctype, dataset, plot_file = file, regresline_lim_left = 1,
                          regresline_lim_right = 6, fig_width = 4, fig_height = 4)

# %% [markdown]
# ### 3D. Boxplot of the stability change median per E3 ligase (CPTAC): WT, non-trunc in, non-trunc out

# %%
conditions = ["wt",
              "nontrunc_in_muts",
              "nontrunc_out_muts"]

palette = {"wt": "#33a02c",  
               "nontrunc_in_muts": "#e31a1c", 
               "nontrunc_out_muts": "#6a3d9a",
               }

# %%
dataset = "CPTAC"
file = os.path.join(plots_path, "stabch_nontrunc_cptac_boxplot.png")

cptac_subset = prepare_subsets_muttype_wthE3_dict(cptac_stabch, conditions, check_normality = False)

# %%
ax = stabch_E3ligase_boxplot(conditions, cptac_subset, dataset, cptac_stabch, -1.5, 1.5, palette, main_plot = "boxplot",
                do_stats = True, stripplot = True, annot_n = False, fig_width = 10, fig_height = 4,
                plot_file = file, pad_stats = 100)
# Out:
# /home/rblanco/anaconda3/envs/degrons/lib/python3.9/site-packages/statannotations/_Plotter.py:337: UserWarning: Invalid x-position found. Are the same parameters passed to seaborn and statannotations calls? or are there few data points?
#   warnings.warn(
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# DEG_APCC_TPR_1_nontrunc_in_muts vs. DEG_APCC_TPR_1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.780e-01 U_stat=1.313e+06
# APC_KENBOX_wt vs. APC_KENBOX_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.820e-01 U_stat=4.590e+06
# APC_KENBOX_nontrunc_in_muts vs. APC_KENBOX_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.326e-01 U_stat=3.261e+04
# CBL_PTK_wt vs. CBL_PTK_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.516e-02 U_stat=2.630e+07
# CBL_PTK_nontrunc_in_muts vs. CBL_PTK_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.125e-01 U_stat=1.561e+05
# FBXW7_wt vs. FBXW7_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.742e-01 U_stat=1.073e+08
# FBXW7_nontrunc_in_muts vs. FBXW7_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.128e-01 U_stat=7.273e+05
# CBL_MET_wt vs. CBL_MET_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.702e-01 U_stat=2.959e+06
# CBL_MET_nontrunc_in_muts vs. CBL_MET_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.784e-01 U_stat=1.613e+04
# DTL_wt vs. DTL_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.738e-01 U_stat=8.004e+03
# DTL_nontrunc_in_muts vs. DTL_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.473e-01 U_stat=8.800e+01
# MDM2_wt vs. MDM2_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.257e-01 U_stat=7.203e+03
# MDM2_nontrunc_in_muts vs. MDM2_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.928e-01 U_stat=7.000e+00
# APC_ABBA_wt vs. APC_ABBA_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.306e-01 U_stat=2.466e+04
# SPOP_wt vs. SPOP_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.635e-03 U_stat=9.151e+08
# SPOP_nontrunc_in_muts vs. SPOP_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.957e-01 U_stat=6.179e+06
# DEG_APCC_TPR_1_wt vs. DEG_APCC_TPR_1_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.290e-03 U_stat=2.196e+08
# APC_ABBA_nontrunc_in_muts vs. APC_ABBA_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.979e-01 U_stat=8.600e+01
# BTRC_wt vs. BTRC_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.200e-03 U_stat=1.787e+05
# BTRC_nontrunc_in_muts vs. BTRC_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.969e-03 U_stat=2.003e+03
# KEAP1_wt vs. KEAP1_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.340e-02 U_stat=1.610e+06
# KEAP1_nontrunc_in_muts vs. KEAP1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.569e-01 U_stat=8.260e+03
# FBXO31_wt vs. FBXO31_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.059e-02 U_stat=1.360e+02
# FBXO31_nontrunc_in_muts vs. FBXO31_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.667e-01 U_stat=7.000e+00
# APC_KENBOX_wt vs. APC_KENBOX_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.897e-03 U_stat=4.558e+07
# CBL_PTK_wt vs. CBL_PTK_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.599e-07 U_stat=1.750e+08
# FBXW7_wt vs. FBXW7_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.600e-09 U_stat=7.566e+08
# CBL_MET_wt vs. CBL_MET_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.704e-01 U_stat=1.017e+07
# DTL_wt vs. DTL_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.536e-01 U_stat=5.306e+04
# MDM2_wt vs. MDM2_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.865e-01 U_stat=1.064e+04
# DEG_APCC_TPR_1_wt vs. DEG_APCC_TPR_1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.122e-09 U_stat=1.755e+09
# SPOP_wt vs. SPOP_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.104e-35 U_stat=1.039e+10
# APC_ABBA_wt vs. APC_ABBA_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.232e-03 U_stat=2.990e+05
# BTRC_wt vs. BTRC_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.279e-01 U_stat=6.056e+05
# KEAP1_wt vs. KEAP1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.233e-01 U_stat=1.465e+07
# FBXO31_wt vs. FBXO31_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.823e-01 U_stat=1.757e+03

# %% [markdown]
# ### S6. Boxplot of the stability change median per E3 ligase (CCLE): WT, non-trunc in, non-trunc out

# %%
conditions = ["wt",
              "nontrunc_in_muts",
              "nontrunc_out_muts"]

palette = {"wt": "#33a02c",  
               "nontrunc_in_muts": "#e31a1c", 
               "nontrunc_out_muts": "#6a3d9a",
               }

# %%
dataset = "CCLE"
file = os.path.join(plots_path, "stabch_nontrunc_ccle_boxplot.png")

ccle_subset = prepare_subsets_muttype_wthE3_dict(ccle_stabch, conditions, check_normality = False)

# %%
ax = stabch_E3ligase_boxplot(conditions, ccle_subset, dataset, ccle_stabch, -1.5, 1.5, palette, main_plot = "boxplot",
                do_stats = True, stripplot = True, annot_n = False, fig_width = 10, fig_height = 4,
                plot_file = file, pad_stats = 100)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# FBXW7_nontrunc_in_muts vs. FBXW7_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.848e-01 U_stat=8.114e+05
# SPOP_wt vs. SPOP_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.577e-01 U_stat=1.602e+08
# SPOP_nontrunc_in_muts vs. SPOP_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.300e-01 U_stat=4.541e+06
# DEG_APCC_TPR_1_wt vs. DEG_APCC_TPR_1_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.465e-02 U_stat=3.633e+07
# DEG_APCC_TPR_1_nontrunc_in_muts vs. DEG_APCC_TPR_1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.473e-01 U_stat=9.359e+05
# DTL_wt vs. DTL_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.088e-01 U_stat=1.969e+03
# DTL_nontrunc_in_muts vs. DTL_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.689e-01 U_stat=7.900e+01
# KEAP1_wt vs. KEAP1_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.910e-01 U_stat=2.446e+05
# KEAP1_nontrunc_in_muts vs. KEAP1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.631e-01 U_stat=6.568e+03
# APC_ABBA_wt vs. APC_ABBA_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.642e-01 U_stat=8.920e+02
# APC_ABBA_nontrunc_in_muts vs. APC_ABBA_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.503e-01 U_stat=2.900e+01
# APC_KENBOX_wt vs. APC_KENBOX_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.750e-01 U_stat=9.290e+05
# APC_KENBOX_nontrunc_in_muts vs. APC_KENBOX_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.849e-01 U_stat=2.872e+04
# FBXO31_wt vs. FBXO31_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.563e-01 U_stat=7.050e+02
# CBL_PTK_wt vs. CBL_PTK_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.074e-01 U_stat=5.274e+06
# CBL_PTK_nontrunc_in_muts vs. CBL_PTK_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.944e-01 U_stat=1.504e+05
# FBXW7_wt vs. FBXW7_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.280e-01 U_stat=2.436e+07
# FBXO31_nontrunc_in_muts vs. FBXO31_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.895e-01 U_stat=9.000e+00
# BTRC_wt vs. BTRC_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.694e-01 U_stat=3.062e+04
# BTRC_nontrunc_in_muts vs. BTRC_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.558e-01 U_stat=8.850e+02
# CBL_MET_wt vs. CBL_MET_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.426e-01 U_stat=5.407e+05
# CBL_MET_nontrunc_in_muts vs. CBL_MET_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.559e-01 U_stat=1.784e+04
# MDM2_wt vs. MDM2_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.057e-01 U_stat=1.270e+02
# MDM2_nontrunc_in_muts vs. MDM2_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.000e-01 U_stat=9.000e+00
# COP1_wt vs. COP1_nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.597e-01 U_stat=3.800e+01
# COP1_nontrunc_in_muts vs. COP1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.667e-01 U_stat=2.000e+00
# SPOP_wt vs. SPOP_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.985e-14 U_stat=1.818e+09
# DEG_APCC_TPR_1_wt vs. DEG_APCC_TPR_1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.043e-12 U_stat=3.306e+08
# DTL_wt vs. DTL_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.110e-01 U_stat=1.192e+04
# KEAP1_wt vs. KEAP1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.422e-05 U_stat=3.581e+06
# APC_ABBA_wt vs. APC_ABBA_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.798e-01 U_stat=5.594e+04
# APC_KENBOX_wt vs. APC_KENBOX_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.081e-03 U_stat=9.179e+06
# FBXW7_wt vs. FBXW7_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.363e-03 U_stat=1.378e+08
# CBL_PTK_wt vs. CBL_PTK_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.205e-09 U_stat=3.645e+07
# FBXO31_wt vs. FBXO31_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.045e-02 U_stat=2.490e+02
# BTRC_wt vs. BTRC_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.769e-02 U_stat=1.231e+05
# CBL_MET_wt vs. CBL_MET_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.012e-01 U_stat=2.091e+06
# MDM2_wt vs. MDM2_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.293e-01 U_stat=4.389e+03
# COP1_wt vs. COP1_nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.974e-01 U_stat=3.400e+01

# %% [markdown]
# ### 3E. BTRC degron in CTNNB1 stability change: WT, non-trunc in, non-trunc out (CPTAC)

# %%
conditions = ["wt",
              "nontrunc_in_muts",
              "nontrunc_out_muts"]

palette = {"wt": "#33a02c",  
               "nontrunc_in_muts": "#e31a1c", 
               "nontrunc_out_muts": "#6a3d9a",
               }

# %%
groups_of_conditions = [["wt", "nontrunc_in_muts", "nontrunc_out_muts"]]

# %%
## BTRC degron in CTNNB1: position

cptac_stabch.loc[(cptac_stabch.E3 == "BTRC") & (cptac_stabch.gene == "CTNNB1")].groupby(
    ["gene", "E3", "degron_start", "degron_end"]).size()
# Out:
# gene    E3    degron_start  degron_end
# CTNNB1  BTRC  27            39            2114
# dtype: int64

# %%
file = os.path.join(plots_path, "stabch_nontrunc_BTRC_CTNNB1_boxplot.png")

dataset = "CPTAC"
E3 = "BTRC"
gene = "CTNNB1"
start = 27            # int64 checked with dtype
end = 39
title = E3+' degron in '+gene+' ('+str(start)+'-'+str(end)+') ('+dataset+')'

cptac_degron_subset = prepare_subsetsDegron_muttype_dict(cptac_stabch, conditions, E3, gene, start, end,
                                                  check_normality = False)

# %%
for group_cond in groups_of_conditions:

    # check whether all conditions exist for this E3 ligase
    if all(cond in list(cptac_degron_subset.keys()) for cond in group_cond):

        pairs = create_all_pairs(group_cond)
            
        ax = stabch_plot(group_cond, pairs, cptac_degron_subset, dataset, cptac_stabch, -1.5, 1.5, palette, main_plot = "boxplot",
                        do_stats = True, stripplot = True, E3 = E3, degron_features = "degron_instance",
                        custom_title = title, fig_width = 4.8, fig_height = 4, plot_file = file, pad_stats = 100)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# wt vs. nontrunc_in_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.096e-07 U_stat=2.980e+03
# nontrunc_in_muts vs. nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.506e-03 U_stat=1.340e+02
# wt vs. nontrunc_out_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.433e-01 U_stat=3.138e+03

# %% [markdown]
# ### 3F. CTNNB1 stability change: needle plot with mutations matched to stability change oscillations

# %%
file = os.path.join(plots_path, "BTRC_CTNNB1_needleplot.png")

stabch_needle_plot("CTNNB1", small_proteome, cptac_stabch, "CPTAC", degron_start = 27, degron_end = 39,
                  degron_name = "BTRC degron", degron_name_fontsize = 9, fig_width = 5, fig_height = 3,
                  plot_file = file)
# Out:
# /home/rblanco/anaconda3/envs/degrons/lib/python3.9/site-packages/matplotlib/axes/_base.py:2475: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %% [markdown]
# ## Figure 4. Effect of degron disruption in truncanting alterations in the last exon. Supplementary S7, S8

# %% [markdown]
# ### 4A. Overall stability change levels comparison (CPTAC): wt, syn, non-truncanting and truncanting

# %%
conditions = ["wt",
              "syn_muts",
              "nontrunc_muts",
              "trunc_muts"]

pairs = [("wt", "trunc_muts"),
        ("syn_muts", "trunc_muts"),
        ("nontrunc_muts", "trunc_muts")]

palette = palette = {"wt": "#33a02c",
                     "syn_muts": "#a6cee3",
                     "nontrunc_muts": "#fb9a99",
                     "trunc_muts": "#fdbf6f"
                    }

# %%
dataset = "CPTAC"

cptac_subset = prepare_subsets_muttype_dict(cptac_stabch, conditions, check_normality = False)

# %%
file = os.path.join(plots_path, "muttypes_cptac_boxplot.png")

ax = stabch_plot(conditions, pairs, cptac_subset, dataset, cptac_stabch, -1.5, 1.5, palette, main_plot = "boxplot",
                do_stats = True, stripplot = True, annot_n = False, fig_width = 5.7, fig_height = 4,
                plot_file = file, pad_stats = 100)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# nontrunc_muts vs. trunc_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.071e-13 U_stat=5.804e+07
# syn_muts vs. trunc_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.521e-17 U_stat=1.989e+07
# wt vs. trunc_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.222e-26 U_stat=5.220e+09

# %% [markdown]
# ### S7A. Overall stability change levels comparison (CCLE): wt, syn, non-truncanting and truncanting

# %%
dataset = "CCLE"

ccle_subset = prepare_subsets_muttype_dict(ccle_stabch, conditions, check_normality = False)

# %%
file = os.path.join(plots_path, "muttypes_ccle_boxplot.png")

ax = stabch_plot(conditions, pairs, ccle_subset, dataset, ccle_stabch, -0.7, 0.7, palette, main_plot = "boxplot",
                do_stats = True, stripplot = True, annot_n = False, fig_width = 5.7, fig_height = 4,
                plot_file = file, pad_stats = 100)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# nontrunc_muts vs. trunc_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:6.103e-13 U_stat=4.132e+07
# syn_muts vs. trunc_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.138e-18 U_stat=1.898e+07
# wt vs. trunc_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.225e-23 U_stat=8.854e+08

# %% [markdown]
# ### 4B. Overall stability change levels comparison (CPTAC): wt, syn, truncanting in/bf, truncanting after

# %%
conditions = ["wt",
              "syn_muts",
              "trunc_inbf_muts",
              "trunc_aft_muts"]

pairs = [("wt", "trunc_inbf_muts"),
        ("syn_muts", "trunc_inbf_muts"),
        ("trunc_inbf_muts", "trunc_aft_muts")]

palette = palette = {"wt": "#33a02c",
                     "syn_muts": "#a6cee3",
                     "trunc_inbf_muts": "#e31a1c",
                     "trunc_aft_muts": "#6a3d9a"
                    }

# %%
# %notify

dataset = "CPTAC"

cptac_subset = prepare_subsets_muttype_dict(cptac_stabch, conditions, check_normality = False)

# %%
file = os.path.join(plots_path, "muttypes_bfaft_cptac_boxplot.png")

ax = stabch_plot(conditions, pairs, cptac_subset, dataset, cptac_stabch, -1.5, 1.5, palette, main_plot = "boxplot",
                do_stats = True, stripplot = True, annot_n = False, fig_width = 5.7, fig_height = 4,
                plot_file = file, pad_stats = 100)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# syn_muts vs. trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.155e-15 U_stat=8.194e+06
# trunc_inbf_muts vs. trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.921e-03 U_stat=1.613e+05
# wt vs. trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.551e-20 U_stat=2.151e+09

# %% [markdown]
# ### S7B. Overall stability change levels comparison (CCLE): wt, syn, truncanting in/bf, truncanting after

# %%
dataset = "CCLE"

ccle_subset = prepare_subsets_muttype_dict(ccle_stabch, conditions, check_normality = False)

# %%
file = os.path.join(plots_path, "muttypes_bfaft_ccle_boxplot.png")

ax = stabch_plot(conditions, pairs, ccle_subset, dataset, ccle_stabch, -0.7, 0.7, palette, main_plot = "boxplot",
                do_stats = True, stripplot = True, annot_n = False, fig_width = 5.7, fig_height = 4,
                plot_file = file, pad_stats = 100)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# syn_muts vs. trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.966e-13 U_stat=8.585e+06
# trunc_inbf_muts vs. trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.509e-02 U_stat=1.071e+05
# wt vs. trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.571e-16 U_stat=4.011e+08

# %% [markdown]
# ### 4C. Stability change median per E3 ligase (CPTAC): WT, trunc in/bf, trunc after

# %%
conditions = ["wt",
              "trunc_inbf_muts",
              "trunc_aft_muts"]

palette = {"wt": "#33a02c",
           "trunc_inbf_muts": "#e31a1c",
           "trunc_aft_muts": "#6a3d9a"}

# %%
dataset = "CPTAC"
file = os.path.join(plots_path, "stabch_trunc_cptac_boxplot.png")

cptac_subset = prepare_subsets_muttype_wthE3_dict(cptac_stabch, conditions, check_normality = False)

# %%
ax = stabch_E3ligase_boxplot(conditions, cptac_subset, dataset, cptac_stabch, -1.5, 1.5, palette, main_plot = "boxplot",
                do_stats = True, stripplot = True, annot_n = False, fig_width = 10, fig_height = 4,
                plot_file = file, pad_stats = 100)
# Out:
# [[('SPOP', 'wt'), ('SPOP', 'trunc_inbf_muts')], [('SPOP', 'wt'), ('SPOP', 'trunc_aft_muts')], [('SPOP', 'trunc_inbf_muts'), ('SPOP', 'trunc_aft_muts')], [('DEG_APCC_TPR_1', 'wt'), ('DEG_APCC_TPR_1', 'trunc_inbf_muts')], [('DEG_APCC_TPR_1', 'wt'), ('DEG_APCC_TPR_1', 'trunc_aft_muts')], [('DEG_APCC_TPR_1', 'trunc_inbf_muts'), ('DEG_APCC_TPR_1', 'trunc_aft_muts')], [('APC_KENBOX', 'wt'), ('APC_KENBOX', 'trunc_inbf_muts')], [('APC_KENBOX', 'wt'), ('APC_KENBOX', 'trunc_aft_muts')], [('APC_KENBOX', 'trunc_inbf_muts'), ('APC_KENBOX', 'trunc_aft_muts')], [('CBL_PTK', 'wt'), ('CBL_PTK', 'trunc_inbf_muts')], [('CBL_PTK', 'wt'), ('CBL_PTK', 'trunc_aft_muts')], [('CBL_PTK', 'trunc_inbf_muts'), ('CBL_PTK', 'trunc_aft_muts')], [('FBXW7', 'wt'), ('FBXW7', 'trunc_inbf_muts')], [('FBXW7', 'wt'), ('FBXW7', 'trunc_aft_muts')], [('FBXW7', 'trunc_inbf_muts'), ('FBXW7', 'trunc_aft_muts')], [('CBL_MET', 'wt'), ('CBL_MET', 'trunc_inbf_muts')], [('CBL_MET', 'wt'), ('CBL_MET', 'trunc_aft_muts')], [('CBL_MET', 'trunc_inbf_muts'), ('CBL_MET', 'trunc_aft_muts')], [('BTRC', 'wt'), ('BTRC', 'trunc_inbf_muts')], [('BTRC', 'wt'), ('BTRC', 'trunc_aft_muts')], [('BTRC', 'trunc_inbf_muts'), ('BTRC', 'trunc_aft_muts')], [('KEAP1', 'wt'), ('KEAP1', 'trunc_inbf_muts')], [('KEAP1', 'wt'), ('KEAP1', 'trunc_aft_muts')], [('KEAP1', 'trunc_inbf_muts'), ('KEAP1', 'trunc_aft_muts')]]
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# DEG_APCC_TPR_1_trunc_inbf_muts vs. DEG_APCC_TPR_1_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.389e-01 U_stat=4.026e+03
# APC_KENBOX_wt vs. APC_KENBOX_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.126e-02 U_stat=3.424e+06
# APC_KENBOX_trunc_inbf_muts vs. APC_KENBOX_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.314e-01 U_stat=2.650e+02
# CBL_PTK_wt vs. CBL_PTK_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.849e-01 U_stat=4.655e+06
# CBL_PTK_trunc_inbf_muts vs. CBL_PTK_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.037e-01 U_stat=3.700e+02
# FBXW7_wt vs. FBXW7_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.022e-07 U_stat=2.856e+07
# FBXW7_trunc_inbf_muts vs. FBXW7_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.335e-01 U_stat=2.066e+03
# CBL_MET_wt vs. CBL_MET_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.585e-03 U_stat=9.646e+05
# CBL_MET_trunc_inbf_muts vs. CBL_MET_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.628e-01 U_stat=1.620e+02
# BTRC_wt vs. BTRC_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.533e-01 U_stat=3.998e+04
# BTRC_trunc_inbf_muts vs. BTRC_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.000e+00 U_stat=3.000e+00
# KEAP1_wt vs. KEAP1_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.710e-02 U_stat=7.100e+05
# KEAP1_trunc_inbf_muts vs. KEAP1_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.231e-01 U_stat=4.400e+01
# SPOP_wt vs. SPOP_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.322e-05 U_stat=1.685e+08
# SPOP_trunc_inbf_muts vs. SPOP_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.405e-01 U_stat=1.350e+04
# DEG_APCC_TPR_1_wt vs. DEG_APCC_TPR_1_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.666e-11 U_stat=6.065e+07
# APC_KENBOX_wt vs. APC_KENBOX_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.619e-01 U_stat=6.594e+05
# CBL_PTK_wt vs. CBL_PTK_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.365e-01 U_stat=1.936e+06
# FBXW7_wt vs. FBXW7_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.194e-02 U_stat=1.320e+07
# CBL_MET_wt vs. CBL_MET_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.386e-03 U_stat=4.998e+05
# BTRC_wt vs. BTRC_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.239e-01 U_stat=9.165e+03
# KEAP1_wt vs. KEAP1_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.583e-01 U_stat=1.790e+05
# DEG_APCC_TPR_1_wt vs. DEG_APCC_TPR_1_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.300e-03 U_stat=3.068e+07
# SPOP_wt vs. SPOP_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.009e-02 U_stat=1.520e+08

# %% [markdown]
# ### S8. Stability change median per E3 ligase (CCLE): WT, trunc in/bf, trunc after

# %%
dataset = "CCLE"
file = os.path.join(plots_path, "stabch_trunc_ccle_boxplot.png")

ccle_subset = prepare_subsets_muttype_wthE3_dict(ccle_stabch, conditions, check_normality = False)

# %%
ax = stabch_E3ligase_boxplot(conditions, ccle_subset, dataset, ccle_stabch, -1.5, 1.5, palette, main_plot = "boxplot",
                do_stats = True, stripplot = True, annot_n = False, fig_width = 10, fig_height = 4,
                plot_file = file, pad_stats = 100)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# FBXW7_trunc_inbf_muts vs. FBXW7_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:3.891e-02 U_stat=1.398e+03
# SPOP_wt vs. SPOP_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.799e-06 U_stat=2.984e+07
# SPOP_trunc_inbf_muts vs. SPOP_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.171e-01 U_stat=6.656e+03
# DEG_APCC_TPR_1_wt vs. DEG_APCC_TPR_1_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.384e-06 U_stat=1.051e+07
# DEG_APCC_TPR_1_trunc_inbf_muts vs. DEG_APCC_TPR_1_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:7.888e-01 U_stat=2.354e+03
# KEAP1_wt vs. KEAP1_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.178e-02 U_stat=2.674e+05
# KEAP1_trunc_inbf_muts vs. KEAP1_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.666e-01 U_stat=4.200e+01
# BTRC_wt vs. BTRC_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:2.997e-02 U_stat=9.922e+03
# BTRC_trunc_inbf_muts vs. BTRC_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:5.714e-01 U_stat=3.000e+00
# CBL_PTK_wt vs. CBL_PTK_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.551e-02 U_stat=1.227e+06
# CBL_PTK_trunc_inbf_muts vs. CBL_PTK_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:9.421e-01 U_stat=3.830e+02
# FBXW7_wt vs. FBXW7_trunc_inbf_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.604e-01 U_stat=3.943e+06
# SPOP_wt vs. SPOP_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:4.367e-03 U_stat=2.030e+07
# DEG_APCC_TPR_1_wt vs. DEG_APCC_TPR_1_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.090e-03 U_stat=4.147e+06
# KEAP1_wt vs. KEAP1_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.881e-02 U_stat=3.041e+04
# BTRC_wt vs. BTRC_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.947e-01 U_stat=2.698e+03
# FBXW7_wt vs. FBXW7_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:8.087e-02 U_stat=1.728e+06
# CBL_PTK_wt vs. CBL_PTK_trunc_aft_muts: Mann-Whitney-Wilcoxon test two-sided, P_val:1.780e-01 U_stat=5.116e+05

# %% [markdown]
# ### 4D. GATA3 stability change: needle plot with mutations matched to stability change oscillations (CPTAC)

# %%
file = os.path.join(plots_path, "FBXW7_GATA3_needleplot.png")

dataset = "CPTAC"
E3 = "FBXW7"
gene = "GATA3"
start = 415            # int64 checked with dtype
end = 425
stabch_needle_plot(gene, small_proteome, cptac_stabch, "CPTAC", degron_start = start, degron_end = end,
                  degron_name = E3+" degron", degron_name_fontsize = 12, fig_width = 5, fig_height = 3,
                  plot_file = file)
